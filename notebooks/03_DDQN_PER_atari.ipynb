# %%
import gymnasium as gym
import torch
import matplotlib.pyplot as plt
import time
import numpy as np
from src.utils.util import ShellColor as sc

print(f"{sc.COLOR_PURPLE}Gym version:{sc.ENDC} {gym.__version__}")
print(f"{sc.COLOR_PURPLE}Pytorch version:{sc.ENDC} {torch.__version__}")

from src.agents import DDQNPerAgent
from src.utils import util as rl_util
# Out:
# Gym version: 0.27.0
# Pytorch version: 1.12.0+cu113

# %%
env_name = "PongNoFrameskip-v4"
env = gym.make(env_name)
env = gym.wrappers.AtariPreprocessing(
    env=env, 
    terminal_on_life_loss=True, 
    grayscale_obs=True, 
    scale_obs=False,
    noop_max=30)
env = gym.wrappers.FrameStack(env, num_stack=4)
rl_util.print_env_info(env=env)
# Out:
# ============ Env Info ===========
# Env id: PongNoFrameskip-v4
# Observation space size: (4, 84, 84)
# Action space size: 6
# Action list: ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']
# =================================
# A.L.E: Arcade Learning Environment (version 0.8.0+919230b)
# [Powered by Stella]

# %%
stacked_obs, info = env.reset()
print(stacked_obs.shape)
n_cols = 4
n_rows = 2
fig = plt.figure(figsize=(16, 9))
for row in range(n_rows):
    for col in range(n_cols):
        ax = fig.add_subplot(n_rows, n_cols, row * n_cols + col + 1)
        ax.imshow(stacked_obs[col], cmap="gray")
        stacked_obs, _, _, _,_ = env.step(env.action_space.sample())
plt.show()
# Out:
# (4, 84, 84)

# %%
config = rl_util.create_config()
config["print_frequency"] = 20
config["mean_reward_bound"] = 10

# %%
agent = DDQNPerAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=True,
    config=config,
)

print(agent.config)
print(type(agent.memory))
# Out:
# Model Initializing... An input shape is (4, 84, 84)
# Model Initializing... An input shape is (4, 84, 84)
# ========== Config Info ==========
# n_episodes: 2000
# max_steps: 2000000
# batch_size: 32
# gamma: 0.99
# lr: 0.0001
# start_training_step: 10000
# learning_frequency: 1
# epsilon_start: 0.95
# epsilon_end: 0.01
# epsilon_decay: 300000.0
# seed: 0
# target_update_frequency: 1000
# buffer_size: 50000
# device: cuda:0
# mean_reward_bound: 10
# print_frequency: 20
# =================================
# <class 'src.commons.memory.prioritized_memory.PrioritizedMemory'>

# %%
save_dir = "result/DDQN/per/atari/"
rl_util.create_directory(save_dir)
current_time = rl_util.get_current_time_string()
save_model_name = save_dir + env_name + "_" + current_time+".pt"

# %%
obs, _ =  env.reset()
episode_returns = []
episode_return = 0
episode_losses = []
episode_loss = 0
episode = 0
best_mean_return = -10000
is_start_train = True

start_time = time.time()
for t in range(agent.config.max_steps):
    epsilon = agent.decay_epsilon(t)
    action = agent.select_action(obs, epsilon)
    next_obs, reward, done, _, _ = env.step(action)
    agent.store_transition(obs, action, reward, next_obs, done)
    episode_return += reward
    
    if t > agent.config.start_training_step:
        if is_start_train:
            print(f"Start Training at timestep {t}...")
            is_start_train = False
            
        episode_loss += agent.update()
        if t % agent.config.target_update_frequency == 0:
            agent.update_target_network()

    if done:
        obs, _ = env.reset()
        episode += 1
        episode_returns.append(episode_return)
        episode_losses.append(episode_loss)
        mean_episode_return = np.mean(episode_returns[-agent.config.print_frequency:])
        mean_episode_loss = np.mean(episode_losses[-agent.config.print_frequency:])

        if episode % agent.config.print_frequency == 0:
            print(
                f"step: {t} | episode: {episode} | cur_return: {episode_return:.4f} | mean_return: {mean_episode_return:.4f} | best_mean_return: {best_mean_return:.4f} | loss: {episode_loss:.4f} | epsilon: {epsilon:.4f}"
            )

        if best_mean_return < mean_episode_return:
            torch.save(agent.policy_network.state_dict(), save_model_name)
            print(f"Best mean return updated {best_mean_return:.3f} -> {mean_episode_return:.3f}, model saved")
            best_mean_return = mean_episode_return
            if mean_episode_return > agent.config.mean_reward_bound:
                print(f"Solved!")
                break 
        episode_return = 0
        episode_loss = 0
    else:
        obs = next_obs

end_time = time.time()
print(f"WorkingTime[{DDQNPerAgent.__name__}]: {end_time-start_time:.4f} sec\n")
# Out:
# Best mean return updated -10000.000 -> -20.000, model saved
# Start Training at timestep 10001...
# step: 17758 | episode: 20 | cur_return: -20.0000 | mean_return: -20.3500 | best_mean_return: -20.0000 | loss: 4.7897 | epsilon: 0.8908
# Best mean return updated -20.000 -> -19.950, model saved
# Best mean return updated -19.950 -> -19.750, model saved
# Best mean return updated -19.750 -> -19.650, model saved
# Best mean return updated -19.650 -> -19.600, model saved
# step: 37855 | episode: 40 | cur_return: -21.0000 | mean_return: -19.6500 | best_mean_return: -19.6000 | loss: 5.4977 | epsilon: 0.8238
# Best mean return updated -19.600 -> -19.550, model saved
# Best mean return updated -19.550 -> -19.500, model saved
# step: 57857 | episode: 60 | cur_return: -21.0000 | mean_return: -20.0000 | best_mean_return: -19.5000 | loss: 6.4234 | epsilon: 0.7571
# Best mean return updated -19.500 -> -19.450, model saved
# Best mean return updated -19.450 -> -19.300, model saved
# step: 80174 | episode: 80 | cur_return: -16.0000 | mean_return: -19.1000 | best_mean_return: -19.3000 | loss: 9.0228 | epsilon: 0.6828
# Best mean return updated -19.300 -> -19.100, model saved
# Best mean return updated -19.100 -> -18.900, model saved
# Best mean return updated -18.900 -> -18.750, model saved
# Best mean return updated -18.750 -> -18.700, model saved
# Best mean return updated -18.700 -> -18.550, model saved
# Best mean return updated -18.550 -> -18.500, model saved
# step: 104194 | episode: 100 | cur_return: -21.0000 | mean_return: -18.8500 | best_mean_return: -18.5000 | loss: 8.9519 | epsilon: 0.6027
# Best mean return updated -18.500 -> -18.350, model saved
# Best mean return updated -18.350 -> -18.300, model saved
# Best mean return updated -18.300 -> -18.200, model saved
# Best mean return updated -18.200 -> -18.150, model saved
# Best mean return updated -18.150 -> -18.100, model saved
# step: 131950 | episode: 120 | cur_return: -19.0000 | mean_return: -18.0000 | best_mean_return: -18.1000 | loss: 9.9527 | epsilon: 0.5102
# Best mean return updated -18.100 -> -18.000, model saved
# Best mean return updated -18.000 -> -17.950, model saved
# Best mean return updated -17.950 -> -17.500, model saved
# Best mean return updated -17.500 -> -17.400, model saved
# Best mean return updated -17.400 -> -17.300, model saved
# step: 163144 | episode: 140 | cur_return: -17.0000 | mean_return: -17.2000 | best_mean_return: -17.3000 | loss: 10.3273 | epsilon: 0.4062
# Best mean return updated -17.300 -> -17.200, model saved
# Best mean return updated -17.200 -> -17.050, model saved
# Best mean return updated -17.050 -> -16.800, model saved
# Best mean return updated -16.800 -> -16.700, model saved
# Best mean return updated -16.700 -> -16.400, model saved
# Best mean return updated -16.400 -> -16.200, model saved
# Best mean return updated -16.200 -> -16.000, model saved
# Best mean return updated -16.000 -> -15.800, model saved
# Best mean return updated -15.800 -> -15.450, model saved
# Best mean return updated -15.450 -> -15.250, model saved
# Best mean return updated -15.250 -> -15.050, model saved
# Best mean return updated -15.050 -> -14.950, model saved
# step: 199721 | episode: 160 | cur_return: -7.0000 | mean_return: -14.4500 | best_mean_return: -14.9500 | loss: 15.9739 | epsilon: 0.2843
# Best mean return updated -14.950 -> -14.450, model saved
# Best mean return updated -14.450 -> -14.400, model saved
# Best mean return updated -14.400 -> -14.250, model saved
# Best mean return updated -14.250 -> -13.950, model saved
# Best mean return updated -13.950 -> -13.700, model saved
# Best mean return updated -13.700 -> -13.100, model saved
# Best mean return updated -13.100 -> -13.050, model saved
# Best mean return updated -13.050 -> -12.100, model saved
# Best mean return updated -12.100 -> -11.650, model saved
# Best mean return updated -11.650 -> -10.950, model saved
# Best mean return updated -10.950 -> -10.850, model saved
# Best mean return updated -10.850 -> -10.550, model saved
# Best mean return updated -10.550 -> -9.400, model saved
# Best mean return updated -9.400 -> -8.950, model saved
# Best mean return updated -8.950 -> -8.150, model saved
# Best mean return updated -8.150 -> -7.600, model saved
# step: 247874 | episode: 180 | cur_return: -1.0000 | mean_return: -7.3000 | best_mean_return: -7.6000 | loss: 18.3427 | epsilon: 0.1238
# Best mean return updated -7.600 -> -7.300, model saved
# Best mean return updated -7.300 -> -6.150, model saved
# Best mean return updated -6.150 -> -4.800, model saved
# Best mean return updated -4.800 -> -4.300, model saved
# Best mean return updated -4.300 -> -2.950, model saved
# Best mean return updated -2.950 -> -1.700, model saved
# Best mean return updated -1.700 -> -0.500, model saved
# Best mean return updated -0.500 -> 0.850, model saved
# Best mean return updated 0.850 -> 1.850, model saved
# Best mean return updated 1.850 -> 2.550, model saved
# Best mean return updated 2.550 -> 3.850, model saved
# Best mean return updated 3.850 -> 4.350, model saved
# Best mean return updated 4.350 -> 5.400, model saved
# Best mean return updated 5.400 -> 6.350, model saved
# Best mean return updated 6.350 -> 7.800, model saved
# Best mean return updated 7.800 -> 9.050, model saved
# Best mean return updated 9.050 -> 9.750, model saved
# Best mean return updated 9.750 -> 10.900, model saved
# Solved!
# WorkingTime[DDQNPerAgent]: 3491.2739 sec

# %%
fig, ax = rl_util.init_2d_figure("Reward")
rl_util.plot_graph(
    ax,
    episode_returns,
    title="reward",
    ylabel="reward",
    save_dir_name=save_dir,
    is_save=True,
)
rl_util.show_figure()
fig, ax = rl_util.init_2d_figure("Loss")
rl_util.plot_graph(
    ax, episode_losses, title="loss", ylabel="loss", save_dir_name=save_dir, is_save=True
)
rl_util.show_figure()
# Out:
# Save result/DDQN/per/atari/reward_2023_02_20_04_18_24.png
# Save result/DDQN/per/atari/loss_2023_02_20_04_18_24.png

# %%
env = gym.make(env_name, render_mode="human")
env = gym.wrappers.AtariPreprocessing(env=env, terminal_on_life_loss=True, grayscale_obs=True,
                                            noop_max=0)
env = gym.wrappers.FrameStack(env, num_stack=4)

test_agent = DDQNPerAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=True,
    config=config
)
test_agent.policy_network.load_state_dict(torch.load(save_model_name))
print(f"Load {save_model_name} model..")
for i_episode in range(1):
    state, _ = env.reset()
    test_reward = 0
    while True:
        env.render()
        action = test_agent.select_action(state, 0.)
        next_state, reward, terminated, truncated, _ = env.step(action)
        test_reward += reward
        state = next_state
        done = terminated or truncated
        if done:
            break
    print(f"{i_episode} episode Total Reward: {test_reward}")
env.close()
# Out:
# Model Initializing... An input shape is (4, 84, 84)
# Model Initializing... An input shape is (4, 84, 84)
# Load result/DDQN/per/atari/PongNoFrameskip-v4_2023_02_20_03_20_12.pt model..
# /home/djjin/anaconda3/envs/test/lib/python3.8/site-packages/gymnasium/utils/passive_env_checker.py:357: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# 0 episode Total Reward: 20.0
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
