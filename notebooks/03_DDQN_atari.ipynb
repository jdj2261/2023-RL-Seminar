# %%
import gymnasium as gym
import torch
import matplotlib.pyplot as plt
import numpy as np
import time
from src.utils.util import ShellColor as sc

print(f"{sc.COLOR_PURPLE}Gym version:{sc.ENDC} {gym.__version__}")
print(f"{sc.COLOR_PURPLE}Pytorch version:{sc.ENDC} {torch.__version__}")

from src.agents import DDQNAgent
from src.utils import util as rl_util
# Out:
# Gym version: 0.27.0
# Pytorch version: 1.12.0+cu113

# %%
env_name = "PongNoFrameskip-v4"
env = gym.make(env_name)
env = gym.wrappers.AtariPreprocessing(
    env=env, 
    terminal_on_life_loss=True, 
    grayscale_obs=True, 
    scale_obs=False,
    noop_max=30)
env = gym.wrappers.FrameStack(env, num_stack=4)
rl_util.print_env_info(env=env)
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.0+919230b)
# [Powered by Stella]
# ============ Env Info ===========
# Env id: PongNoFrameskip-v4
# Observation space size: (4, 84, 84)
# Action space size: 6
# Action list: ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']
# =================================

# %%
stacked_obs, info = env.reset()
print(stacked_obs.shape)
n_cols = 4
n_rows = 2
fig = plt.figure(figsize=(16, 9))
for row in range(n_rows):
    for col in range(n_cols):
        ax = fig.add_subplot(n_rows, n_cols, row * n_cols + col + 1)
        ax.imshow(stacked_obs[col], cmap="gray")
        stacked_obs, _, _, _,_ = env.step(env.action_space.sample())
plt.show()
# Out:
# (4, 84, 84)

# %%
config = rl_util.create_config()
config["print_frequency"] = 20
config["mean_reward_bound"] = 10

# %%
agent = DDQNAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=True,
    config=config,
)

print(agent.config)
print(type(agent.memory))
# Out:
# Model Initializing... An input shape is (4, 84, 84)
# Model Initializing... An input shape is (4, 84, 84)
# ========== Config Info ==========
# n_episodes: 2000
# max_steps: 2000000
# batch_size: 32
# gamma: 0.99
# lr: 0.0001
# start_training_step: 10000
# learning_frequency: 1
# epsilon_start: 0.95
# epsilon_end: 0.01
# epsilon_decay: 300000.0
# seed: 0
# target_update_frequency: 1000
# buffer_size: 50000
# device: cuda:0
# mean_reward_bound: 10
# print_frequency: 20
# =================================
# <class 'src.commons.memory.replay_memory.ReplayMemory'>

# %%
save_dir = "result/DDQN/atari/"
rl_util.create_directory(save_dir)
current_time = rl_util.get_current_time_string()
save_model_name = save_dir + env_name + "_" + current_time+".pt"

# %%
save_model_name
# Out:
# 'result/DDQN/atari/PongNoFrameskip-v4_2023_02_19_11_22_13.pt'

# %%
obs, _ =  env.reset()
episode_returns = []
episode_return = 0
episode_losses = []
episode_loss = 0
episode = 0
best_mean_return = -10000
is_start_train = True

start_time = time.time()
for t in range(agent.config.max_steps):
    epsilon = agent.decay_epsilon(t)
    action = agent.select_action(obs, epsilon)
    next_obs, reward, done, _, _ = env.step(action)
    agent.store_transition(obs, action, reward, next_obs, done)
    episode_return += reward
    
    if t > agent.config.start_training_step:
        if is_start_train:
            print(f"Start Training at timestep {t}...")
            is_start_train = False
            
        episode_loss += agent.update()
        if t % agent.config.target_update_frequency == 0:
            agent.update_target_network()

    if done:
        obs, _ = env.reset()
        episode += 1
        episode_returns.append(episode_return)
        episode_losses.append(episode_loss)
        mean_episode_return = np.mean(episode_returns[-agent.config.print_frequency:])
        mean_episode_loss = np.mean(episode_losses[-agent.config.print_frequency:])

        if episode % agent.config.print_frequency == 0:
            print(
                f"step: {t} | episode: {episode} | cur_return: {episode_return:.4f} | mean_return: {mean_episode_return:.4f} | best_mean_return: {best_mean_return:.4f} | loss: {episode_loss:.4f} | epsilon: {epsilon:.4f}"
            )

        if best_mean_return < mean_episode_return:
            torch.save(agent.policy_network.state_dict(), save_model_name)
            print(f"Best mean return updated {best_mean_return:.3f} -> {mean_episode_return:.3f}, model saved")
            best_mean_return = mean_episode_return
            if mean_episode_return > agent.config.mean_reward_bound:
                print(f"Solved!")
                break
                
        episode_return = 0
        episode_loss = 0
    else:
        obs = next_obs

end_time = time.time()
print(f"WorkingTime[{DDQNAgent.__name__}]: {end_time-start_time:.4f} sec\n")
# Out:
# Best mean return updated -10000.000 -> -20.000, model saved
# Start Training at timestep 10001...
# step: 18473 | episode: 20 | cur_return: -20.0000 | mean_return: -20.2500 | best_mean_return: -20.0000 | loss: 11.3641 | epsilon: 0.8884
# Best mean return updated -20.000 -> -19.950, model saved
# Best mean return updated -19.950 -> -19.850, model saved
# step: 37138 | episode: 40 | cur_return: -20.0000 | mean_return: -20.0500 | best_mean_return: -19.8500 | loss: 9.2908 | epsilon: 0.8262
# Best mean return updated -19.850 -> -19.800, model saved
# step: 55697 | episode: 60 | cur_return: -20.0000 | mean_return: -19.9500 | best_mean_return: -19.8000 | loss: 3.9984 | epsilon: 0.7643
# Best mean return updated -19.800 -> -19.750, model saved
# step: 74924 | episode: 80 | cur_return: -20.0000 | mean_return: -19.9500 | best_mean_return: -19.7500 | loss: 3.8383 | epsilon: 0.7003
# step: 93089 | episode: 100 | cur_return: -21.0000 | mean_return: -20.5000 | best_mean_return: -19.7500 | loss: 2.1945 | epsilon: 0.6397
# step: 112379 | episode: 120 | cur_return: -21.0000 | mean_return: -20.2500 | best_mean_return: -19.7500 | loss: 2.6510 | epsilon: 0.5754
# Best mean return updated -19.750 -> -19.600, model saved
# Best mean return updated -19.600 -> -19.500, model saved
# Best mean return updated -19.500 -> -19.450, model saved
# Best mean return updated -19.450 -> -19.300, model saved
# Best mean return updated -19.300 -> -19.250, model saved
# step: 133875 | episode: 140 | cur_return: -19.0000 | mean_return: -19.2500 | best_mean_return: -19.2500 | loss: 3.6499 | epsilon: 0.5037
# Best mean return updated -19.250 -> -19.150, model saved
# Best mean return updated -19.150 -> -19.100, model saved
# Best mean return updated -19.100 -> -18.950, model saved
# Best mean return updated -18.950 -> -18.900, model saved
# step: 158894 | episode: 160 | cur_return: -17.0000 | mean_return: -18.8000 | best_mean_return: -18.9000 | loss: 5.7174 | epsilon: 0.4204
# Best mean return updated -18.900 -> -18.800, model saved
# Best mean return updated -18.800 -> -18.750, model saved
# Best mean return updated -18.750 -> -18.700, model saved
# Best mean return updated -18.700 -> -18.500, model saved
# step: 185196 | episode: 180 | cur_return: -16.0000 | mean_return: -18.4500 | best_mean_return: -18.5000 | loss: 8.0861 | epsilon: 0.3327
# Best mean return updated -18.500 -> -18.450, model saved
# Best mean return updated -18.450 -> -18.250, model saved
# Best mean return updated -18.250 -> -18.200, model saved
# Best mean return updated -18.200 -> -18.000, model saved
# Best mean return updated -18.000 -> -17.900, model saved
# Best mean return updated -17.900 -> -17.700, model saved
# Best mean return updated -17.700 -> -17.600, model saved
# Best mean return updated -17.600 -> -17.400, model saved
# Best mean return updated -17.400 -> -17.200, model saved
# Best mean return updated -17.200 -> -17.100, model saved
# Best mean return updated -17.100 -> -17.050, model saved
# Best mean return updated -17.050 -> -16.950, model saved
# Best mean return updated -16.950 -> -16.850, model saved
# Best mean return updated -16.850 -> -16.800, model saved
# Best mean return updated -16.800 -> -16.500, model saved
# Best mean return updated -16.500 -> -16.450, model saved
# Best mean return updated -16.450 -> -16.400, model saved
# step: 218482 | episode: 200 | cur_return: -19.0000 | mean_return: -16.6500 | best_mean_return: -16.4000 | loss: 6.9515 | epsilon: 0.2217
# Best mean return updated -16.400 -> -16.350, model saved
# Best mean return updated -16.350 -> -16.300, model saved
# Best mean return updated -16.300 -> -16.150, model saved
# Best mean return updated -16.150 -> -15.850, model saved
# Best mean return updated -15.850 -> -15.700, model saved
# step: 257284 | episode: 220 | cur_return: -14.0000 | mean_return: -15.7000 | best_mean_return: -15.7000 | loss: 8.3900 | epsilon: 0.0924
# Best mean return updated -15.700 -> -15.500, model saved
# Best mean return updated -15.500 -> -15.400, model saved
# Best mean return updated -15.400 -> -15.000, model saved
# Best mean return updated -15.000 -> -14.950, model saved
# Best mean return updated -14.950 -> -14.900, model saved
# Best mean return updated -14.900 -> -14.850, model saved
# Best mean return updated -14.850 -> -14.750, model saved
# Best mean return updated -14.750 -> -14.500, model saved
# Best mean return updated -14.500 -> -14.450, model saved
# Best mean return updated -14.450 -> -14.100, model saved
# Best mean return updated -14.100 -> -13.950, model saved
# Best mean return updated -13.950 -> -13.800, model saved
# step: 308410 | episode: 240 | cur_return: -11.0000 | mean_return: -13.6500 | best_mean_return: -13.8000 | loss: 8.8610 | epsilon: 0.0100
# Best mean return updated -13.800 -> -13.650, model saved
# Best mean return updated -13.650 -> -13.400, model saved
# Best mean return updated -13.400 -> -13.250, model saved
# Best mean return updated -13.250 -> -13.100, model saved
# Best mean return updated -13.100 -> -13.000, model saved
# Best mean return updated -13.000 -> -12.900, model saved
# Best mean return updated -12.900 -> -12.750, model saved
# Best mean return updated -12.750 -> -12.300, model saved
# Best mean return updated -12.300 -> -12.150, model saved
# Best mean return updated -12.150 -> -11.050, model saved
# step: 363947 | episode: 260 | cur_return: -11.0000 | mean_return: -11.0500 | best_mean_return: -11.0500 | loss: 8.6495 | epsilon: 0.0100
# Best mean return updated -11.050 -> -10.800, model saved
# Best mean return updated -10.800 -> -10.550, model saved
# Best mean return updated -10.550 -> -10.450, model saved
# Best mean return updated -10.450 -> -10.250, model saved
# Best mean return updated -10.250 -> -9.500, model saved
# Best mean return updated -9.500 -> -9.250, model saved
# Best mean return updated -9.250 -> -9.200, model saved
# Best mean return updated -9.200 -> -8.800, model saved
# Best mean return updated -8.800 -> -8.450, model saved
# Best mean return updated -8.450 -> -8.050, model saved
# step: 426580 | episode: 280 | cur_return: 5.0000 | mean_return: -7.9000 | best_mean_return: -8.0500 | loss: 10.0939 | epsilon: 0.0100
# Best mean return updated -8.050 -> -7.900, model saved
# Best mean return updated -7.900 -> -7.100, model saved
# Best mean return updated -7.100 -> -6.200, model saved
# Best mean return updated -6.200 -> -5.150, model saved
# Best mean return updated -5.150 -> -4.500, model saved
# Best mean return updated -4.500 -> -4.100, model saved
# Best mean return updated -4.100 -> -3.350, model saved
# Best mean return updated -3.350 -> -2.550, model saved
# Best mean return updated -2.550 -> -2.000, model saved
# Best mean return updated -2.000 -> -0.700, model saved
# Best mean return updated -0.700 -> 1.000, model saved
# Best mean return updated 1.000 -> 1.750, model saved
# Best mean return updated 1.750 -> 3.000, model saved
# Best mean return updated 3.000 -> 4.500, model saved
# Best mean return updated 4.500 -> 5.900, model saved
# Best mean return updated 5.900 -> 7.000, model saved
# Best mean return updated 7.000 -> 8.000, model saved
# Best mean return updated 8.000 -> 9.200, model saved
# step: 478227 | episode: 300 | cur_return: 18.0000 | mean_return: 9.8500 | best_mean_return: 9.2000 | loss: 3.4481 | epsilon: 0.0100
# Best mean return updated 9.200 -> 9.850, model saved
# Best mean return updated 9.850 -> 11.350, model saved
# Best mean return updated 11.350 -> 12.300, model saved
# Best mean return updated 12.300 -> 12.750, model saved
# Best mean return updated 12.750 -> 13.400, model saved
# Best mean return updated 13.400 -> 14.200, model saved
# Best mean return updated 14.200 -> 14.950, model saved
# Best mean return updated 14.950 -> 15.700, model saved
# Best mean return updated 15.700 -> 16.150, model saved
# Best mean return updated 16.150 -> 16.300, model saved
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 22
#      19     print(f"Start Training at timestep {t}...")
#      20     is_start_train = False
# ---> 22 episode_loss += agent.update()
#      23 if t % agent.config.target_update_frequency == 0:
#      24     agent.update_target_network()
#
# File ~/Mygit/2023-RL-Seminar/src/agents/ddqn_agent.py:55, in DDQNAgent.update(self)
#      54 def update(self):
# ---> 55     states, actions, rewards, next_states, dones = self.memory.sample(
#      56         self.config.batch_size
#      57     )
#      59     states = torch.from_numpy(np.array(states)).float().to(self.config.device)
#      60     actions = torch.from_numpy(actions).long().to(self.config.device).reshape(-1, 1)
#
# File ~/Mygit/2023-RL-Seminar/src/commons/memory/replay_memory.py:22, in ReplayMemory.sample(self, batch_size)
#      20     actions.append(np.array(action, copy=False))
#      21     rewards.append(np.array(reward, copy=False))
# ---> 22     next_states.append(np.array(next_state, copy=False))
#      23     dones.append(np.array(done, copy=False))
#      25 return (
#      26     np.array(states),
#      27     np.array(actions),
#    (...)
#      30     np.array(dones),
#      31 )
#
# File ~/anaconda3/envs/test/lib/python3.8/site-packages/gymnasium/wrappers/frame_stack.py:57, in LazyFrames.__array__(self, dtype)
#      48 def __array__(self, dtype=None):
#      49     """Gets a numpy array of stacked frames with specific dtype.
#      50
#      51     Args:
#    (...)
#      55         The array of stacked frames with dtype
#      56     """
# ---> 57     arr = self[:]
#      58     if dtype is not None:
#      59         return arr.astype(dtype)
#
# File ~/anaconda3/envs/test/lib/python3.8/site-packages/gymnasium/wrappers/frame_stack.py:82, in LazyFrames.__getitem__(self, int_or_slice)
#      80 if isinstance(int_or_slice, int):
#      81     return self._check_decompress(self._frames[int_or_slice])  # single frame
# ---> 82 return np.stack(
#      83     [self._check_decompress(f) for f in self._frames[int_or_slice]], axis=0
#      84 )
#
# File <__array_function__ internals>:180, in stack(*args, **kwargs)
#
# File ~/anaconda3/envs/test/lib/python3.8/site-packages/numpy/core/shape_base.py:433, in stack(arrays, axis, out)
#     431 sl = (slice(None),) * axis + (_nx.newaxis,)
#     432 expanded_arrays = [arr[sl] for arr in arrays]
# --> 433 return _nx.concatenate(expanded_arrays, axis=axis, out=out)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
fig, ax = rl_util.init_2d_figure("Reward")
rl_util.plot_graph(
    ax,
    episode_returns,
    title="reward",
    ylabel="reward",
    save_dir_name=save_dir,
    is_save=True,
)
rl_util.show_figure()
fig, ax = rl_util.init_2d_figure("Loss")
rl_util.plot_graph(
    ax, episode_losses, title="loss", ylabel="loss", save_dir_name=save_dir, is_save=True
)
rl_util.show_figure()
# Out:
# Save result/DDQN/atari/reward_2023_02_20_12_41_46.png
# Save result/DDQN/atari/loss_2023_02_20_12_41_46.png

# %%
env = gym.make(env_name, render_mode="human")
env = gym.wrappers.AtariPreprocessing(env=env, terminal_on_life_loss=True, grayscale_obs=True,
                                            noop_max=0)
env = gym.wrappers.FrameStack(env, num_stack=4)

test_agent = DDQNAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=True,
    config=config
)
test_agent.policy_network.load_state_dict(torch.load(save_model_name))

for i_episode in range(1):
    state, _ = env.reset()
    test_reward = 0
    while True:
        env.render()
        action = test_agent.select_action(state, 0.)
        next_state, reward, terminated, truncated, _ = env.step(action)
        test_reward += reward
        state = next_state
        done = terminated or truncated
        if done:
            break
    print(f"{i_episode} episode Total Reward: {test_reward}")
env.close()
