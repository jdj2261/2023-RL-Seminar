# %%
import gymnasium as gym
import torch
import matplotlib.pyplot as plt
import time
import numpy as np
from src.utils.util import ShellColor as sc

print(f"{sc.COLOR_PURPLE}Gym version:{sc.ENDC} {gym.__version__}")
print(f"{sc.COLOR_PURPLE}Pytorch version:{sc.ENDC} {torch.__version__}")

from src.agents.dqn_per_agent import DQNPerAgent
from src.utils import util as rl_util
# Out:
# Gym version: 0.27.0
# Pytorch version: 1.12.0+cu113

# %%
env_name = "PongNoFrameskip-v4"
env = gym.make(env_name)
env = gym.wrappers.AtariPreprocessing(
    env=env, 
    terminal_on_life_loss=True, 
    grayscale_obs=True, 
    scale_obs=False,
    noop_max=30)
env = gym.wrappers.FrameStack(env, num_stack=4)
rl_util.print_env_info(env=env)
# Out:
# ============ Env Info ===========
# Env id: PongNoFrameskip-v4
# Observation space size: (4, 84, 84)
# Action space size: 6
# Action list: ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']
# =================================
# A.L.E: Arcade Learning Environment (version 0.8.0+919230b)
# [Powered by Stella]

# %%
stacked_obs, info = env.reset()
print(stacked_obs.shape)
n_cols = 4
n_rows = 2
fig = plt.figure(figsize=(16, 9))
for row in range(n_rows):
    for col in range(n_cols):
        ax = fig.add_subplot(n_rows, n_cols, row * n_cols + col + 1)
        ax.imshow(stacked_obs[col], cmap="gray")
        stacked_obs, _, _, _,_ = env.step(env.action_space.sample())
plt.show()
# Out:
# (4, 84, 84)

# %%
config = rl_util.create_config()
config["print_frequency"] = 20
config["mean_reward_bound"] = 10

# %%
agent = DQNPerAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=True,
    config=config,
)

print(agent.config)
print(type(agent.memory))
# Out:
# Model Initializing... An input shape is (4, 84, 84)
# Model Initializing... An input shape is (4, 84, 84)
# ========== Config Info ==========
# n_episodes: 2000
# max_steps: 2000000
# batch_size: 32
# gamma: 0.99
# lr: 0.0001
# start_training_step: 10000
# learning_frequency: 1
# epsilon_start: 0.95
# epsilon_end: 0.01
# epsilon_decay: 300000.0
# seed: 0
# target_update_frequency: 1000
# buffer_size: 50000
# device: cuda:0
# mean_reward_bound: 10
# print_frequency: 20
# =================================
# <class 'src.commons.memory.prioritized_memory.PrioritizedMemory'>

# %%
save_dir = "result/DQN/per/atari/"
rl_util.create_directory(save_dir)
current_time = rl_util.get_current_time_string()
save_model_name = save_dir + env_name + "_" + current_time+".pt"

# %%
save_model_name
# Out:
# 'result/DQN/per/atariPongNoFrameskip-v4_2023_02_19_10_04_56.pt'

# %%
obs, _ =  env.reset()
episode_returns = []
episode_return = 0
episode_losses = []
episode_loss = 0
episode = 0
best_mean_return = -10000
is_start_train = True

start_time = time.time()
for t in range(agent.config.max_steps):
    epsilon = agent.decay_epsilon(t)
    action = agent.select_action(obs, epsilon)
    next_obs, reward, done, _, _ = env.step(action)
    agent.store_transition(obs, action, reward, next_obs, done)
    episode_return += reward
    
    if t > agent.config.start_training_step:
        if is_start_train:
            print(f"Start Training at timestep {t}...")
            is_start_train = False
            
        episode_loss += agent.update()
        if t % agent.config.target_update_frequency == 0:
            agent.update_target_network()

    if done:
        obs, _ = env.reset()
        episode += 1
        episode_returns.append(episode_return)
        episode_losses.append(episode_loss)
        mean_episode_return = np.mean(episode_returns[-agent.config.print_frequency:])
        mean_episode_loss = np.mean(episode_losses[-agent.config.print_frequency:])

        if episode % agent.config.print_frequency == 0:
            print(
                f"step: {t} | episode: {episode} | cur_return: {episode_return:.4f} | mean_return: {mean_episode_return:.4f} | best_mean_return: {best_mean_return:.4f} | loss: {episode_loss:.4f} | epsilon: {epsilon:.4f}"
            )

        if best_mean_return < mean_episode_return:
            torch.save(agent.policy_network.state_dict(), save_model_name)
            print(f"Best mean return updated {best_mean_return:.3f} -> {mean_episode_return:.3f}, model saved")
            best_mean_return = mean_episode_return
            if mean_episode_return > 10:
                print(f"Solved!")
                break 
        episode_return = 0
        episode_loss = 0
    else:
        obs = next_obs

end_time = time.time()
print(f"WorkingTime[{DQNPerAgent.__name__}]: {end_time-start_time:.4f} sec\n")
# Out:
# Best mean reward updated -10000.000 -> -21.000, model saved
# Best mean reward updated -21.000 -> -20.800, model saved
# Start Training at timestep 10001...
# Best mean reward updated -20.800 -> -20.714, model saved
# Best mean reward updated -20.714 -> -20.667, model saved
# Best mean reward updated -20.667 -> -20.625, model saved
# step: 17164 | episode: 20 | cur_return: -21.0000 | mean_return: -20.6500 | best_mean_return: -20.6250 | loss: 5.9651 | epsilon: 0.8928
# Best mean reward updated -20.625 -> -20.500, model saved
# Best mean reward updated -20.500 -> -20.450, model saved
# Best mean reward updated -20.450 -> -20.400, model saved
# Best mean reward updated -20.400 -> -20.350, model saved
# Best mean reward updated -20.350 -> -20.300, model saved
# Best mean reward updated -20.300 -> -20.200, model saved
# Best mean reward updated -20.200 -> -20.150, model saved
# Best mean reward updated -20.150 -> -20.100, model saved
# Best mean reward updated -20.100 -> -20.000, model saved
# Best mean reward updated -20.000 -> -19.950, model saved
# Best mean reward updated -19.950 -> -19.900, model saved
# Best mean reward updated -19.900 -> -19.750, model saved
# step: 37417 | episode: 40 | cur_return: -20.0000 | mean_return: -19.7500 | best_mean_return: -19.7500 | loss: 8.5585 | epsilon: 0.8253
# Best mean reward updated -19.750 -> -19.600, model saved
# Best mean reward updated -19.600 -> -19.550, model saved
# Best mean reward updated -19.550 -> -19.500, model saved
# Best mean reward updated -19.500 -> -19.450, model saved
# step: 59239 | episode: 60 | cur_return: -20.0000 | mean_return: -19.7000 | best_mean_return: -19.4500 | loss: 8.4394 | epsilon: 0.7525
# Best mean reward updated -19.450 -> -19.350, model saved
# Best mean reward updated -19.350 -> -19.300, model saved
# Best mean reward updated -19.300 -> -19.200, model saved
# Best mean reward updated -19.200 -> -19.050, model saved
# Best mean reward updated -19.050 -> -19.000, model saved
# step: 83650 | episode: 80 | cur_return: -19.0000 | mean_return: -18.9500 | best_mean_return: -19.0000 | loss: 14.0056 | epsilon: 0.6712
# Best mean reward updated -19.000 -> -18.950, model saved
# Best mean reward updated -18.950 -> -18.900, model saved
# Best mean reward updated -18.900 -> -18.850, model saved
# Best mean reward updated -18.850 -> -18.750, model saved
# Best mean reward updated -18.750 -> -18.700, model saved
# Best mean reward updated -18.700 -> -18.650, model saved
# Best mean reward updated -18.650 -> -18.600, model saved
# step: 108977 | episode: 100 | cur_return: -20.0000 | mean_return: -19.2500 | best_mean_return: -18.6000 | loss: 10.1196 | epsilon: 0.5867
# Best mean reward updated -18.600 -> -18.550, model saved
# Best mean reward updated -18.550 -> -18.500, model saved
# Best mean reward updated -18.500 -> -18.350, model saved
# Best mean reward updated -18.350 -> -18.300, model saved
# Best mean reward updated -18.300 -> -18.250, model saved
# Best mean reward updated -18.250 -> -17.900, model saved
# step: 139675 | episode: 120 | cur_return: -17.0000 | mean_return: -17.7500 | best_mean_return: -17.9000 | loss: 15.4460 | epsilon: 0.4844
# Best mean reward updated -17.900 -> -17.750, model saved
# Best mean reward updated -17.750 -> -17.700, model saved
# Best mean reward updated -17.700 -> -17.600, model saved
# Best mean reward updated -17.600 -> -17.200, model saved
# Best mean reward updated -17.200 -> -16.850, model saved
# Best mean reward updated -16.850 -> -16.700, model saved
# Best mean reward updated -16.700 -> -16.350, model saved
# step: 174808 | episode: 140 | cur_return: -12.0000 | mean_return: -16.3500 | best_mean_return: -16.3500 | loss: 16.2477 | epsilon: 0.3673
# Best mean reward updated -16.350 -> -16.250, model saved
# Best mean reward updated -16.250 -> -16.050, model saved
# Best mean reward updated -16.050 -> -15.900, model saved
# Best mean reward updated -15.900 -> -15.600, model saved
# Best mean reward updated -15.600 -> -15.250, model saved
# Best mean reward updated -15.250 -> -15.200, model saved
# Best mean reward updated -15.200 -> -14.900, model saved
# Best mean reward updated -14.900 -> -14.800, model saved
# Best mean reward updated -14.800 -> -14.600, model saved
# Best mean reward updated -14.600 -> -14.550, model saved
# step: 215325 | episode: 160 | cur_return: -10.0000 | mean_return: -14.7000 | best_mean_return: -14.5500 | loss: 22.1793 | epsilon: 0.2322
# Best mean reward updated -14.550 -> -14.250, model saved
# Best mean reward updated -14.250 -> -14.200, model saved
# Best mean reward updated -14.200 -> -13.450, model saved
# Best mean reward updated -13.450 -> -13.250, model saved
# Best mean reward updated -13.250 -> -12.450, model saved
# Best mean reward updated -12.450 -> -11.850, model saved
# Best mean reward updated -11.850 -> -10.800, model saved
# Best mean reward updated -10.800 -> -9.900, model saved
# step: 266630 | episode: 180 | cur_return: 8.0000 | mean_return: -9.0000 | best_mean_return: -9.9000 | loss: 20.7040 | epsilon: 0.0612
# Best mean reward updated -9.900 -> -9.000, model saved
# Best mean reward updated -9.000 -> -8.000, model saved
# Best mean reward updated -8.000 -> -6.500, model saved
# Best mean reward updated -6.500 -> -5.550, model saved
# Best mean reward updated -5.550 -> -4.400, model saved
# Best mean reward updated -4.400 -> -3.300, model saved
# Best mean reward updated -3.300 -> -2.750, model saved
# Best mean reward updated -2.750 -> -1.300, model saved
# Best mean reward updated -1.300 -> 0.050, model saved
# Best mean reward updated 0.050 -> 1.050, model saved
# Best mean reward updated 1.050 -> 2.000, model saved
# Best mean reward updated 2.000 -> 2.900, model saved
# Best mean reward updated 2.900 -> 3.950, model saved
# Best mean reward updated 3.950 -> 4.550, model saved
# Best mean reward updated 4.550 -> 5.700, model saved
# Best mean reward updated 5.700 -> 6.550, model saved
# Best mean reward updated 6.550 -> 7.750, model saved
# Best mean reward updated 7.750 -> 8.350, model saved
# Best mean reward updated 8.350 -> 9.850, model saved
# Best mean reward updated 9.850 -> 10.550, model saved
# Solved!

# %%
fig, ax = rl_util.init_2d_figure("Reward")
rl_util.plot_graph(
    ax,
    episode_returns,
    title="reward",
    ylabel="reward",
    save_dir_name=save_dir,
    is_save=True,
)
rl_util.show_figure()
fig, ax = rl_util.init_2d_figure("Loss")
rl_util.plot_graph(
    ax, episode_losses, title="loss", ylabel="loss", save_dir_name=save_dir, is_save=True
)
rl_util.show_figure()
# Out:
# Save result/DQN/per/atarireward_2023_02_19_11_00_06.png
# Save result/DQN/per/atariloss_2023_02_19_11_00_07.png

# %%
env = gym.make(env_name, render_mode="human")
env = gym.wrappers.AtariPreprocessing(env=env, terminal_on_life_loss=True, grayscale_obs=True,
                                            noop_max=0)
env = gym.wrappers.FrameStack(env, num_stack=4)

test_agent = DQNPerAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=True,
    config=config
)
test_agent.policy_network.load_state_dict(torch.load(save_model_name))

for i_episode in range(1):
    state, _ = env.reset()
    test_reward = 0
    while True:
        env.render()
        action = test_agent.select_action(state, 0.)
        next_state, reward, terminated, truncated, _ = env.step(action)
        test_reward += reward
        state = next_state
        done = terminated or truncated
        if done:
            break
    print(f"{i_episode} episode Total Reward: {test_reward}")
env.close()
# Out:
# Model Initializing... An input shape is (4, 84, 84)
# Model Initializing... An input shape is (4, 84, 84)
# /home/djjin/anaconda3/envs/test/lib/python3.8/site-packages/gymnasium/utils/passive_env_checker.py:357: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# 0 episode Total Reward: 18.0
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
