# %%
import gymnasium as gym
import torch
import matplotlib.pyplot as plt
import time
import numpy as np
from src.utils.util import ShellColor as sc

print(f"{sc.COLOR_PURPLE}Gym version:{sc.ENDC} {gym.__version__}")
print(f"{sc.COLOR_PURPLE}Pytorch version:{sc.ENDC} {torch.__version__}")

from src.agents.dqn_per_agent import DQNPerAgent
from src.utils import util as rl_util
# Out:
# Gym version: 0.27.0
# Pytorch version: 1.12.0+cu113

# %%
env_name = "PongNoFrameskip-v4"
env = gym.make(env_name)
env = gym.wrappers.AtariPreprocessing(
    env=env, 
    terminal_on_life_loss=True, 
    grayscale_obs=True, 
    scale_obs=False,
    noop_max=30)
env = gym.wrappers.FrameStack(env, num_stack=4)
rl_util.print_env_info(env=env)
# Out:
# ============ Env Info ===========
# Env id: PongNoFrameskip-v4
# Observation space size: (4, 84, 84)
# Action space size: 6
# Action list: ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']
# =================================
# A.L.E: Arcade Learning Environment (version 0.8.0+919230b)
# [Powered by Stella]

# %%
stacked_obs, info = env.reset()
print(stacked_obs.shape)
n_cols = 4
n_rows = 2
fig = plt.figure(figsize=(16, 9))
for row in range(n_rows):
    for col in range(n_cols):
        ax = fig.add_subplot(n_rows, n_cols, row * n_cols + col + 1)
        ax.imshow(stacked_obs[col], cmap="gray")
        stacked_obs, _, _, _,_ = env.step(env.action_space.sample())
plt.show()
# Out:
# (4, 84, 84)

# %%
config = rl_util.create_config()
config["print_frequency"] = 20
config["mean_reward_bound"] = 10

# %%
agent = DQNPerAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=True,
    config=config,
)

print(agent.config)
print(type(agent.memory))
# Out:
# Model Initializing... An input shape is (4, 84, 84)
# Model Initializing... An input shape is (4, 84, 84)
# ========== Config Info ==========
# n_episodes: 2000
# max_steps: 2000000
# batch_size: 32
# gamma: 0.99
# lr: 0.0001
# start_training_step: 10000
# learning_frequency: 1
# epsilon_start: 0.95
# epsilon_end: 0.01
# epsilon_decay: 300000.0
# seed: 0
# target_update_frequency: 1000
# buffer_size: 50000
# device: cuda:0
# mean_reward_bound: 10
# print_frequency: 20
# =================================
# <class 'src.commons.memory.prioritized_memory.PrioritizedMemory'>

# %%
save_dir = "result/DQN/per/atari/"
rl_util.create_directory(save_dir)
current_time = rl_util.get_current_time_string()
save_model_name = save_dir + env_name + "_" + current_time+".pt"

# %%
save_model_name
# Out:
# 'result/DQN/per/atari/PongNoFrameskip-v4_2023_02_20_03_20_23.pt'

# %%
obs, _ =  env.reset()
episode_returns = []
episode_return = 0
episode_losses = []
episode_loss = 0
episode = 0
best_mean_return = -10000
is_start_train = True

start_time = time.time()
for t in range(agent.config.max_steps):
    epsilon = agent.decay_epsilon(t)
    action = agent.select_action(obs, epsilon)
    next_obs, reward, done, _, _ = env.step(action)
    agent.store_transition(obs, action, reward, next_obs, done)
    episode_return += reward
    
    if t > agent.config.start_training_step:
        if is_start_train:
            print(f"Start Training at timestep {t}...")
            is_start_train = False
            
        episode_loss += agent.update()
        if t % agent.config.target_update_frequency == 0:
            agent.update_target_network()

    if done:
        obs, _ = env.reset()
        episode += 1
        episode_returns.append(episode_return)
        episode_losses.append(episode_loss)
        mean_episode_return = np.mean(episode_returns[-agent.config.print_frequency:])
        mean_episode_loss = np.mean(episode_losses[-agent.config.print_frequency:])

        if episode % agent.config.print_frequency == 0:
            print(
                f"step: {t} | episode: {episode} | cur_return: {episode_return:.4f} | mean_return: {mean_episode_return:.4f} | best_mean_return: {best_mean_return:.4f} | loss: {episode_loss:.4f} | epsilon: {epsilon:.4f}"
            )

        if best_mean_return < mean_episode_return:
            torch.save(agent.policy_network.state_dict(), save_model_name)
            print(f"Best mean return updated {best_mean_return:.3f} -> {mean_episode_return:.3f}, model saved")
            best_mean_return = mean_episode_return
            if mean_episode_return > agent.config.mean_reward_bound:
                print(f"Solved!")
                break 
        episode_return = 0
        episode_loss = 0
    else:
        obs = next_obs

end_time = time.time()
print(f"WorkingTime[{DQNPerAgent.__name__}]: {end_time-start_time:.4f} sec\n")
# Out:
# Best mean return updated -10000.000 -> -21.000, model saved
# Best mean return updated -21.000 -> -20.800, model saved
# Best mean return updated -20.800 -> -20.667, model saved
# Best mean return updated -20.667 -> -20.556, model saved
# Best mean return updated -20.556 -> -20.545, model saved
# Start Training at timestep 10001...
# Best mean return updated -20.545 -> -20.538, model saved
# step: 17810 | episode: 20 | cur_return: -21.0000 | mean_return: -20.6500 | best_mean_return: -20.5385 | loss: 3.0021 | epsilon: 0.8906
# Best mean return updated -20.538 -> -20.450, model saved
# Best mean return updated -20.450 -> -20.400, model saved
# Best mean return updated -20.400 -> -20.350, model saved
# Best mean return updated -20.350 -> -20.300, model saved
# Best mean return updated -20.300 -> -20.250, model saved
# step: 37102 | episode: 40 | cur_return: -20.0000 | mean_return: -20.2000 | best_mean_return: -20.2500 | loss: 5.8130 | epsilon: 0.8263
# Best mean return updated -20.250 -> -20.200, model saved
# Best mean return updated -20.200 -> -20.150, model saved
# Best mean return updated -20.150 -> -20.100, model saved
# Best mean return updated -20.100 -> -20.050, model saved
# Best mean return updated -20.050 -> -19.900, model saved
# step: 58973 | episode: 60 | cur_return: -18.0000 | mean_return: -19.8500 | best_mean_return: -19.9000 | loss: 7.0969 | epsilon: 0.7534
# Best mean return updated -19.900 -> -19.850, model saved
# Best mean return updated -19.850 -> -19.750, model saved
# Best mean return updated -19.750 -> -19.700, model saved
# Best mean return updated -19.700 -> -19.500, model saved
# Best mean return updated -19.500 -> -19.400, model saved
# Best mean return updated -19.400 -> -19.350, model saved
# Best mean return updated -19.350 -> -19.200, model saved
# Best mean return updated -19.200 -> -19.150, model saved
# Best mean return updated -19.150 -> -19.100, model saved
# Best mean return updated -19.100 -> -18.900, model saved
# Best mean return updated -18.900 -> -18.700, model saved
# Best mean return updated -18.700 -> -18.650, model saved
# step: 83074 | episode: 80 | cur_return: -19.0000 | mean_return: -18.8000 | best_mean_return: -18.6500 | loss: 8.9671 | epsilon: 0.6731
# Best mean return updated -18.650 -> -18.500, model saved
# Best mean return updated -18.500 -> -18.450, model saved
# Best mean return updated -18.450 -> -18.400, model saved
# step: 109926 | episode: 100 | cur_return: -18.0000 | mean_return: -18.4000 | best_mean_return: -18.4000 | loss: 9.9734 | epsilon: 0.5836
# Best mean return updated -18.400 -> -18.300, model saved
# Best mean return updated -18.300 -> -18.200, model saved
# Best mean return updated -18.200 -> -18.150, model saved
# step: 138772 | episode: 120 | cur_return: -18.0000 | mean_return: -18.4000 | best_mean_return: -18.1500 | loss: 10.0685 | epsilon: 0.4874
# Best mean return updated -18.150 -> -17.800, model saved
# Best mean return updated -17.800 -> -17.600, model saved
# Best mean return updated -17.600 -> -17.200, model saved
# Best mean return updated -17.200 -> -17.050, model saved
# Best mean return updated -17.050 -> -16.900, model saved
# Best mean return updated -16.900 -> -16.850, model saved
# Best mean return updated -16.850 -> -16.750, model saved
# step: 170235 | episode: 140 | cur_return: -18.0000 | mean_return: -16.8500 | best_mean_return: -16.7500 | loss: 10.8819 | epsilon: 0.3825
# Best mean return updated -16.750 -> -16.500, model saved
# Best mean return updated -16.500 -> -16.350, model saved
# Best mean return updated -16.350 -> -16.200, model saved
# Best mean return updated -16.200 -> -15.950, model saved
# Best mean return updated -15.950 -> -15.750, model saved
# Best mean return updated -15.750 -> -15.600, model saved
# Best mean return updated -15.600 -> -15.500, model saved
# Best mean return updated -15.500 -> -15.350, model saved
# step: 207934 | episode: 160 | cur_return: -20.0000 | mean_return: -15.6000 | best_mean_return: -15.3500 | loss: 9.0265 | epsilon: 0.2569
# Best mean return updated -15.350 -> -15.300, model saved
# Best mean return updated -15.300 -> -15.000, model saved
# Best mean return updated -15.000 -> -14.850, model saved
# Best mean return updated -14.850 -> -14.400, model saved
# step: 252035 | episode: 180 | cur_return: -11.0000 | mean_return: -13.9500 | best_mean_return: -14.4000 | loss: 14.8858 | epsilon: 0.1099
# Best mean return updated -14.400 -> -13.950, model saved
# Best mean return updated -13.950 -> -13.650, model saved
# Best mean return updated -13.650 -> -13.150, model saved
# Best mean return updated -13.150 -> -12.950, model saved
# Best mean return updated -12.950 -> -11.850, model saved
# Best mean return updated -11.850 -> -11.650, model saved
# Best mean return updated -11.650 -> -10.550, model saved
# Best mean return updated -10.550 -> -10.150, model saved
# Best mean return updated -10.150 -> -9.350, model saved
# Best mean return updated -9.350 -> -8.750, model saved
# Best mean return updated -8.750 -> -8.050, model saved
# Best mean return updated -8.050 -> -6.500, model saved
# Best mean return updated -6.500 -> -5.150, model saved
# Best mean return updated -5.150 -> -3.550, model saved
# Best mean return updated -3.550 -> -2.200, model saved
# Best mean return updated -2.200 -> -1.100, model saved
# Best mean return updated -1.100 -> 0.200, model saved
# Best mean return updated 0.200 -> 0.300, model saved
# Best mean return updated 0.300 -> 1.650, model saved
# Best mean return updated 1.650 -> 2.950, model saved
# step: 307145 | episode: 200 | cur_return: -1.0000 | mean_return: 3.4500 | best_mean_return: 2.9500 | loss: 14.8931 | epsilon: 0.0100
# Best mean return updated 2.950 -> 3.450, model saved
# Best mean return updated 3.450 -> 4.600, model saved
# Best mean return updated 4.600 -> 5.700, model saved
# Best mean return updated 5.700 -> 7.350, model saved
# Best mean return updated 7.350 -> 7.900, model saved
# Best mean return updated 7.900 -> 8.600, model saved
# Best mean return updated 8.600 -> 9.000, model saved
# Best mean return updated 9.000 -> 9.750, model saved
# Best mean return updated 9.750 -> 10.600, model saved
# Solved!
# WorkingTime[DQNPerAgent]: 3667.4417 sec

# %%
fig, ax = rl_util.init_2d_figure("Reward")
rl_util.plot_graph(
    ax,
    episode_returns,
    title="reward",
    ylabel="reward",
    save_dir_name=save_dir,
    is_save=True,
)
rl_util.show_figure()
fig, ax = rl_util.init_2d_figure("Loss")
rl_util.plot_graph(
    ax, episode_losses, title="loss", ylabel="loss", save_dir_name=save_dir, is_save=True
)
rl_util.show_figure()
# Out:
# Save result/DQN/per/atari/reward_2023_02_20_04_21_31.png
# Save result/DQN/per/atari/loss_2023_02_20_04_21_31.png

# %%
env = gym.make(env_name, render_mode="human")
env = gym.wrappers.AtariPreprocessing(env=env, terminal_on_life_loss=True, grayscale_obs=True,
                                            noop_max=0)
env = gym.wrappers.FrameStack(env, num_stack=4)

test_agent = DQNPerAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=True,
    config=config
)
test_agent.policy_network.load_state_dict(torch.load(save_model_name))

for i_episode in range(1):
    state, _ = env.reset()
    test_reward = 0
    while True:
        env.render()
        action = test_agent.select_action(state, 0.)
        next_state, reward, terminated, truncated, _ = env.step(action)
        test_reward += reward
        state = next_state
        done = terminated or truncated
        if done:
            break
    print(f"{i_episode} episode Total Reward: {test_reward}")
env.close()
# Out:
# Model Initializing... An input shape is (4, 84, 84)
# Model Initializing... An input shape is (4, 84, 84)
# /home/djjin/anaconda3/envs/test/lib/python3.8/site-packages/gymnasium/utils/passive_env_checker.py:357: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# 0 episode Total Reward: 20.0
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
