# %%
import gymnasium as gym
import torch
import numpy as np
import time
import matplotlib.pyplot as plt

from src.utils.util import ShellColor as sc

print(f"{sc.COLOR_PURPLE}Gym version:{sc.ENDC} {gym.__version__}")
print(f"{sc.COLOR_PURPLE}Pytorch version:{sc.ENDC} {torch.__version__}")

from src.agents import DuelingDQNAgent
from src.utils import util as rl_util
# Out:
# Gym version: 0.28.1
# Pytorch version: 2.0.0+cu117

# %%
env_name = "BreakoutNoFrameskip-v4"
env = gym.make(env_name)
env = gym.wrappers.AtariPreprocessing(
    env=env, 
    terminal_on_life_loss=True, 
    grayscale_obs=True, 
    scale_obs=False,
    noop_max=30)
env = gym.wrappers.FrameStack(env, num_stack=4)
rl_util.print_env_info(env=env)
# Out:
# ============ Env Info ===========
# Env id: BreakoutNoFrameskip-v4
# Observation space size: (4, 84, 84)
# Action space size: 4
# Action list: ['NOOP', 'FIRE', 'RIGHT', 'LEFT']
# =================================
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]

# %%
stacked_obs, info = env.reset()
print(stacked_obs.shape)
n_cols = 4
n_rows = 2
fig = plt.figure(figsize=(16, 9))
for row in range(n_rows):
    for col in range(n_cols):
        ax = fig.add_subplot(n_rows, n_cols, row * n_cols + col + 1)
        ax.imshow(stacked_obs[col], cmap="gray")
        stacked_obs, _, _, _,_ = env.step(env.action_space.sample())
plt.show()
# Out:
# (4, 84, 84)

# %%
config = rl_util.create_config()
config["print_frequency"] = 50
config["mean_reward_bound"] = 200

# %%
agent = DuelingDQNAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=True,
    config=config,
)

print(agent.config)
print(type(agent.memory))
# Out:
# Model Initializing... An input shape is (4, 84, 84)
# Model Initializing... An input shape is (4, 84, 84)
# ========== Config Info ==========
# n_episodes: 2000
# max_steps: 2000000
# batch_size: 32
# gamma: 0.99
# lr: 0.0001
# start_training_step: 10000
# learning_frequency: 1
# epsilon_start: 0.95
# epsilon_end: 0.01
# epsilon_decay: 300000.0
# seed: 0
# target_update_frequency: 1000
# buffer_size: 50000
# device: cuda:0
# mean_reward_bound: 200
# print_frequency: 50
# =================================
# <class 'src.commons.memory.replay_memory.ReplayMemory'>

# %%
save_dir = "result/DuelingDQN/atari/"
rl_util.create_directory(save_dir)
current_time = rl_util.get_current_time_string()
save_model_name = save_dir + env_name + "_" + current_time + ".pt"

# %%
save_model_name
# Out:
# 'result/DuelingDQN/atari/BreakoutNoFrameskip-v4_2023_07_05_06_34_20.pt'

# %%
obs, _ =  env.reset()
episode_returns = []
episode_return = 0
episode_losses = []
episode_loss = 0
episode = 0
best_mean_return = -10000
is_start_train = True

start_time = time.time()
for t in range(agent.config.max_steps):
    epsilon = agent.decay_epsilon(t)
    action = agent.select_action(obs, epsilon)
    next_obs, reward, done, _, _ = env.step(action)
    agent.store_transition(obs, action, reward, next_obs, done)
    episode_return += reward
    
    if t > agent.config.start_training_step:
        if is_start_train:
            print(f"Start Training at timestep {t}...")
            is_start_train = False
            
        episode_loss += agent.update()
        if t % agent.config.target_update_frequency == 0:
            agent.update_target_network()

    if done:
        obs, _ = env.reset()
        episode += 1
        episode_returns.append(episode_return)
        episode_losses.append(episode_loss)
        mean_episode_return = np.mean(episode_returns[-agent.config.print_frequency:])
        mean_episode_loss = np.mean(episode_losses[-agent.config.print_frequency:])

        if episode % agent.config.print_frequency == 0:
            print(
                f"step: {t} | episode: {episode} | cur_return: {episode_return:.4f} | mean_return: {mean_episode_return:.4f} | best_mean_return: {best_mean_return:.4f} | loss: {episode_loss:.4f} | epsilon: {epsilon:.4f}"
            )

        if best_mean_return < mean_episode_return:
            torch.save(agent.policy_network.state_dict(), save_model_name)
            print(f"Best mean return updated {best_mean_return:.3f} -> {mean_episode_return:.3f}, model saved")
            best_mean_return = mean_episode_return
            if mean_episode_return > agent.config.mean_reward_bound: 
                print(f"Solved!")
                break
                
        episode_return = 0
        episode_loss = 0
    else:
        obs = next_obs
end_time = time.time()
print(f"WorkingTime[{DuelingDQNAgent.__name__}]: {end_time-start_time:.4f} sec\n")
# Out:
# Best mean return updated -10000.000 -> 0.000, model saved
# Best mean return updated 0.000 -> 0.333, model saved
# Best mean return updated 0.333 -> 0.750, model saved
# step: 1989 | episode: 50 | cur_return: 0.0000 | mean_return: 0.2800 | best_mean_return: 0.7500 | loss: 0.0000 | epsilon: 0.9434
# step: 3822 | episode: 100 | cur_return: 0.0000 | mean_return: 0.2400 | best_mean_return: 0.7500 | loss: 0.0000 | epsilon: 0.9373
# step: 5529 | episode: 150 | cur_return: 0.0000 | mean_return: 0.1600 | best_mean_return: 0.7500 | loss: 0.0000 | epsilon: 0.9316
# step: 7177 | episode: 200 | cur_return: 0.0000 | mean_return: 0.1600 | best_mean_return: 0.7500 | loss: 0.0000 | epsilon: 0.9261
# step: 9283 | episode: 250 | cur_return: 0.0000 | mean_return: 0.3600 | best_mean_return: 0.7500 | loss: 0.0000 | epsilon: 0.9191
# Start Training at timestep 10001...
# step: 11284 | episode: 300 | cur_return: 0.0000 | mean_return: 0.3400 | best_mean_return: 0.7500 | loss: 0.1388 | epsilon: 0.9124
# step: 13532 | episode: 350 | cur_return: 0.0000 | mean_return: 0.4200 | best_mean_return: 0.7500 | loss: 0.0213 | epsilon: 0.9049
# step: 15793 | episode: 400 | cur_return: 0.0000 | mean_return: 0.4600 | best_mean_return: 0.7500 | loss: 0.0081 | epsilon: 0.8974
# step: 17744 | episode: 450 | cur_return: 0.0000 | mean_return: 0.3000 | best_mean_return: 0.7500 | loss: 0.0062 | epsilon: 0.8909
# step: 19636 | episode: 500 | cur_return: 1.0000 | mean_return: 0.2600 | best_mean_return: 0.7500 | loss: 0.0192 | epsilon: 0.8845
# step: 21367 | episode: 550 | cur_return: 0.0000 | mean_return: 0.1400 | best_mean_return: 0.7500 | loss: 0.0157 | epsilon: 0.8788
# step: 23116 | episode: 600 | cur_return: 0.0000 | mean_return: 0.2000 | best_mean_return: 0.7500 | loss: 0.0415 | epsilon: 0.8729
# step: 25007 | episode: 650 | cur_return: 1.0000 | mean_return: 0.2200 | best_mean_return: 0.7500 | loss: 0.0577 | epsilon: 0.8666
# step: 27196 | episode: 700 | cur_return: 1.0000 | mean_return: 0.3800 | best_mean_return: 0.7500 | loss: 0.1312 | epsilon: 0.8593
# step: 29489 | episode: 750 | cur_return: 1.0000 | mean_return: 0.5000 | best_mean_return: 0.7500 | loss: 0.0778 | epsilon: 0.8517
# step: 31145 | episode: 800 | cur_return: 0.0000 | mean_return: 0.1400 | best_mean_return: 0.7500 | loss: 0.0411 | epsilon: 0.8462
# step: 33003 | episode: 850 | cur_return: 0.0000 | mean_return: 0.2200 | best_mean_return: 0.7500 | loss: 0.0219 | epsilon: 0.8400
# step: 35038 | episode: 900 | cur_return: 0.0000 | mean_return: 0.3400 | best_mean_return: 0.7500 | loss: 0.0637 | epsilon: 0.8332
# step: 36947 | episode: 950 | cur_return: 0.0000 | mean_return: 0.2600 | best_mean_return: 0.7500 | loss: 0.0296 | epsilon: 0.8268
# step: 39526 | episode: 1000 | cur_return: 1.0000 | mean_return: 0.6000 | best_mean_return: 0.7500 | loss: 0.1936 | epsilon: 0.8182
# Best mean return updated 0.750 -> 0.760, model saved
# step: 42178 | episode: 1050 | cur_return: 0.0000 | mean_return: 0.6800 | best_mean_return: 0.7600 | loss: 0.0623 | epsilon: 0.8094
# step: 44943 | episode: 1100 | cur_return: 0.0000 | mean_return: 0.7000 | best_mean_return: 0.7600 | loss: 0.0644 | epsilon: 0.8002
# Best mean return updated 0.760 -> 0.780, model saved
# Best mean return updated 0.780 -> 0.800, model saved
# Best mean return updated 0.800 -> 0.820, model saved
# Best mean return updated 0.820 -> 0.840, model saved
# Best mean return updated 0.840 -> 0.880, model saved
# Best mean return updated 0.880 -> 0.900, model saved
# Best mean return updated 0.900 -> 0.920, model saved
# Best mean return updated 0.920 -> 0.940, model saved
# Best mean return updated 0.940 -> 0.980, model saved
# Best mean return updated 0.980 -> 1.000, model saved
# Best mean return updated 1.000 -> 1.020, model saved
# step: 47749 | episode: 1150 | cur_return: 0.0000 | mean_return: 0.8000 | best_mean_return: 1.0200 | loss: 0.0624 | epsilon: 0.7908
# step: 50523 | episode: 1200 | cur_return: 1.0000 | mean_return: 0.7600 | best_mean_return: 1.0200 | loss: 0.2932 | epsilon: 0.7816
# step: 53250 | episode: 1250 | cur_return: 1.0000 | mean_return: 0.7800 | best_mean_return: 1.0200 | loss: 0.3177 | epsilon: 0.7725
# step: 55655 | episode: 1300 | cur_return: 2.0000 | mean_return: 0.5600 | best_mean_return: 1.0200 | loss: 0.7268 | epsilon: 0.7645
# step: 58152 | episode: 1350 | cur_return: 0.0000 | mean_return: 0.6200 | best_mean_return: 1.0200 | loss: 0.2202 | epsilon: 0.7562
# step: 60735 | episode: 1400 | cur_return: 0.0000 | mean_return: 0.6400 | best_mean_return: 1.0200 | loss: 0.2152 | epsilon: 0.7475
# step: 63187 | episode: 1450 | cur_return: 3.0000 | mean_return: 0.6000 | best_mean_return: 1.0200 | loss: 1.2686 | epsilon: 0.7394
# step: 65724 | episode: 1500 | cur_return: 0.0000 | mean_return: 0.6200 | best_mean_return: 1.0200 | loss: 0.1773 | epsilon: 0.7309
# step: 67927 | episode: 1550 | cur_return: 0.0000 | mean_return: 0.4800 | best_mean_return: 1.0200 | loss: 0.3001 | epsilon: 0.7236
# step: 70899 | episode: 1600 | cur_return: 2.0000 | mean_return: 0.8400 | best_mean_return: 1.0200 | loss: 1.0334 | epsilon: 0.7137
# Best mean return updated 1.020 -> 1.060, model saved
# Best mean return updated 1.060 -> 1.100, model saved
# Best mean return updated 1.100 -> 1.120, model saved
# step: 74108 | episode: 1650 | cur_return: 4.0000 | mean_return: 0.9800 | best_mean_return: 1.1200 | loss: 1.5523 | epsilon: 0.7030
# step: 76548 | episode: 1700 | cur_return: 2.0000 | mean_return: 0.5800 | best_mean_return: 1.1200 | loss: 0.8587 | epsilon: 0.6948
# step: 78957 | episode: 1750 | cur_return: 1.0000 | mean_return: 0.4800 | best_mean_return: 1.1200 | loss: 0.4001 | epsilon: 0.6868
# step: 82103 | episode: 1800 | cur_return: 1.0000 | mean_return: 0.9200 | best_mean_return: 1.1200 | loss: 0.4065 | epsilon: 0.6763
# Best mean return updated 1.120 -> 1.180, model saved
# Best mean return updated 1.180 -> 1.240, model saved
# step: 85231 | episode: 1850 | cur_return: 2.0000 | mean_return: 0.9400 | best_mean_return: 1.2400 | loss: 1.2879 | epsilon: 0.6659
# step: 88249 | episode: 1900 | cur_return: 1.0000 | mean_return: 0.9000 | best_mean_return: 1.2400 | loss: 0.5215 | epsilon: 0.6558
# step: 91149 | episode: 1950 | cur_return: 0.0000 | mean_return: 0.8600 | best_mean_return: 1.2400 | loss: 0.2241 | epsilon: 0.6462
# step: 94460 | episode: 2000 | cur_return: 2.0000 | mean_return: 1.0400 | best_mean_return: 1.2400 | loss: 1.1061 | epsilon: 0.6351
# Best mean return updated 1.240 -> 1.280, model saved
# step: 97776 | episode: 2050 | cur_return: 0.0000 | mean_return: 1.0600 | best_mean_return: 1.2800 | loss: 0.1840 | epsilon: 0.6241
# step: 100585 | episode: 2100 | cur_return: 0.0000 | mean_return: 0.7400 | best_mean_return: 1.2800 | loss: 0.2909 | epsilon: 0.6147
# step: 103817 | episode: 2150 | cur_return: 3.0000 | mean_return: 1.0800 | best_mean_return: 1.2800 | loss: 1.7120 | epsilon: 0.6039
# step: 106629 | episode: 2200 | cur_return: 1.0000 | mean_return: 0.7200 | best_mean_return: 1.2800 | loss: 0.6394 | epsilon: 0.5946
# step: 110134 | episode: 2250 | cur_return: 0.0000 | mean_return: 1.1400 | best_mean_return: 1.2800 | loss: 0.4083 | epsilon: 0.5829
# step: 112994 | episode: 2300 | cur_return: 1.0000 | mean_return: 0.8200 | best_mean_return: 1.2800 | loss: 0.7373 | epsilon: 0.5734
# step: 116554 | episode: 2350 | cur_return: 0.0000 | mean_return: 1.1800 | best_mean_return: 1.2800 | loss: 0.3746 | epsilon: 0.5615
# Best mean return updated 1.280 -> 1.320, model saved
# step: 120142 | episode: 2400 | cur_return: 0.0000 | mean_return: 1.2400 | best_mean_return: 1.3200 | loss: 0.3579 | epsilon: 0.5495
# step: 122939 | episode: 2450 | cur_return: 0.0000 | mean_return: 0.7400 | best_mean_return: 1.3200 | loss: 0.2189 | epsilon: 0.5402
# step: 126201 | episode: 2500 | cur_return: 2.0000 | mean_return: 0.9600 | best_mean_return: 1.3200 | loss: 1.4751 | epsilon: 0.5293
# Best mean return updated 1.320 -> 1.360, model saved
# Best mean return updated 1.360 -> 1.380, model saved
# Best mean return updated 1.380 -> 1.420, model saved
# Best mean return updated 1.420 -> 1.480, model saved
# Best mean return updated 1.480 -> 1.500, model saved
# Best mean return updated 1.500 -> 1.580, model saved
# step: 130403 | episode: 2550 | cur_return: 0.0000 | mean_return: 1.5400 | best_mean_return: 1.5800 | loss: 0.2877 | epsilon: 0.5153
# Best mean return updated 1.580 -> 1.600, model saved
# step: 133935 | episode: 2600 | cur_return: 0.0000 | mean_return: 1.2400 | best_mean_return: 1.6000 | loss: 0.3262 | epsilon: 0.5035
# Best mean return updated 1.600 -> 1.620, model saved
# step: 138247 | episode: 2650 | cur_return: 1.0000 | mean_return: 1.6400 | best_mean_return: 1.6200 | loss: 0.6211 | epsilon: 0.4892
# Best mean return updated 1.620 -> 1.640, model saved
# Best mean return updated 1.640 -> 1.660, model saved
# step: 141799 | episode: 2700 | cur_return: 1.0000 | mean_return: 1.2400 | best_mean_return: 1.6600 | loss: 0.8879 | epsilon: 0.4773
# step: 145569 | episode: 2750 | cur_return: 1.0000 | mean_return: 1.3000 | best_mean_return: 1.6600 | loss: 1.0875 | epsilon: 0.4648
# Best mean return updated 1.660 -> 1.680, model saved
# Best mean return updated 1.680 -> 1.700, model saved
# Best mean return updated 1.700 -> 1.720, model saved
# Best mean return updated 1.720 -> 1.800, model saved
# step: 149878 | episode: 2800 | cur_return: 2.0000 | mean_return: 1.6000 | best_mean_return: 1.8000 | loss: 1.6375 | epsilon: 0.4504
# Best mean return updated 1.800 -> 1.900, model saved
# Best mean return updated 1.900 -> 1.920, model saved
# Best mean return updated 1.920 -> 1.980, model saved
# Best mean return updated 1.980 -> 2.000, model saved
# Best mean return updated 2.000 -> 2.040, model saved
# Best mean return updated 2.040 -> 2.080, model saved
# Best mean return updated 2.080 -> 2.100, model saved
# step: 154901 | episode: 2850 | cur_return: 6.0000 | mean_return: 2.1400 | best_mean_return: 2.1000 | loss: 3.7229 | epsilon: 0.4337
# Best mean return updated 2.100 -> 2.140, model saved
# Best mean return updated 2.140 -> 2.180, model saved
# Best mean return updated 2.180 -> 2.260, model saved
# Best mean return updated 2.260 -> 2.340, model saved
# Best mean return updated 2.340 -> 2.380, model saved
# Best mean return updated 2.380 -> 2.520, model saved
# step: 160360 | episode: 2900 | cur_return: 4.0000 | mean_return: 2.3000 | best_mean_return: 2.5200 | loss: 1.9471 | epsilon: 0.4155
# step: 165016 | episode: 2950 | cur_return: 3.0000 | mean_return: 1.8600 | best_mean_return: 2.5200 | loss: 2.6076 | epsilon: 0.3999
# step: 170073 | episode: 3000 | cur_return: 1.0000 | mean_return: 2.1800 | best_mean_return: 2.5200 | loss: 0.9136 | epsilon: 0.3831
# Best mean return updated 2.520 -> 2.560, model saved
# Best mean return updated 2.560 -> 2.640, model saved
# Best mean return updated 2.640 -> 2.660, model saved
# Best mean return updated 2.660 -> 2.720, model saved
# step: 175344 | episode: 3050 | cur_return: 0.0000 | mean_return: 2.2200 | best_mean_return: 2.7200 | loss: 0.4418 | epsilon: 0.3655
# step: 180976 | episode: 3100 | cur_return: 2.0000 | mean_return: 2.6000 | best_mean_return: 2.7200 | loss: 1.2490 | epsilon: 0.3467
# step: 185914 | episode: 3150 | cur_return: 0.0000 | mean_return: 2.0000 | best_mean_return: 2.7200 | loss: 0.4419 | epsilon: 0.3303
# step: 191013 | episode: 3200 | cur_return: 1.0000 | mean_return: 2.1200 | best_mean_return: 2.7200 | loss: 1.0495 | epsilon: 0.3133
# Best mean return updated 2.720 -> 2.780, model saved
# Best mean return updated 2.780 -> 2.800, model saved
# step: 197029 | episode: 3250 | cur_return: 1.0000 | mean_return: 2.6600 | best_mean_return: 2.8000 | loss: 0.8291 | epsilon: 0.2932
# step: 203133 | episode: 3300 | cur_return: 0.0000 | mean_return: 2.7600 | best_mean_return: 2.8000 | loss: 0.3974 | epsilon: 0.2729
# Best mean return updated 2.800 -> 2.820, model saved
# Best mean return updated 2.820 -> 2.840, model saved
# Best mean return updated 2.840 -> 2.880, model saved
# Best mean return updated 2.880 -> 2.960, model saved
# Best mean return updated 2.960 -> 3.040, model saved
# Best mean return updated 3.040 -> 3.080, model saved
# Best mean return updated 3.080 -> 3.140, model saved
# Best mean return updated 3.140 -> 3.220, model saved
# Best mean return updated 3.220 -> 3.340, model saved
# Best mean return updated 3.340 -> 3.360, model saved
# Best mean return updated 3.360 -> 3.440, model saved
# Best mean return updated 3.440 -> 3.580, model saved
# Best mean return updated 3.580 -> 3.620, model saved
# step: 209245 | episode: 3350 | cur_return: 4.0000 | mean_return: 2.6800 | best_mean_return: 3.6200 | loss: 2.9874 | epsilon: 0.2525
# step: 215519 | episode: 3400 | cur_return: 3.0000 | mean_return: 3.0200 | best_mean_return: 3.6200 | loss: 2.4250 | epsilon: 0.2316
# Best mean return updated 3.620 -> 3.640, model saved
# Best mean return updated 3.640 -> 3.680, model saved
# Best mean return updated 3.680 -> 3.740, model saved
# Best mean return updated 3.740 -> 3.800, model saved
# Best mean return updated 3.800 -> 3.860, model saved
# Best mean return updated 3.860 -> 3.880, model saved
# step: 222432 | episode: 3450 | cur_return: 4.0000 | mean_return: 3.4200 | best_mean_return: 3.8800 | loss: 2.0299 | epsilon: 0.2086
# step: 228766 | episode: 3500 | cur_return: 3.0000 | mean_return: 3.0800 | best_mean_return: 3.8800 | loss: 1.5425 | epsilon: 0.1874
# step: 235665 | episode: 3550 | cur_return: 2.0000 | mean_return: 3.2600 | best_mean_return: 3.8800 | loss: 1.3865 | epsilon: 0.1644
# step: 243443 | episode: 3600 | cur_return: 1.0000 | mean_return: 3.8600 | best_mean_return: 3.8800 | loss: 0.7246 | epsilon: 0.1385
# step: 251013 | episode: 3650 | cur_return: 5.0000 | mean_return: 3.8400 | best_mean_return: 3.8800 | loss: 1.6972 | epsilon: 0.1133
# Best mean return updated 3.880 -> 3.980, model saved
# Best mean return updated 3.980 -> 4.120, model saved
# Best mean return updated 4.120 -> 4.180, model saved
# Best mean return updated 4.180 -> 4.280, model saved
# Best mean return updated 4.280 -> 4.360, model saved
# Best mean return updated 4.360 -> 4.400, model saved
# Best mean return updated 4.400 -> 4.420, model saved
# Best mean return updated 4.420 -> 4.500, model saved
# Best mean return updated 4.500 -> 4.560, model saved
# Best mean return updated 4.560 -> 4.600, model saved
# step: 258813 | episode: 3700 | cur_return: 1.0000 | mean_return: 4.3200 | best_mean_return: 4.6000 | loss: 0.5290 | epsilon: 0.0873
# Best mean return updated 4.600 -> 4.740, model saved
# Best mean return updated 4.740 -> 4.760, model saved
# Best mean return updated 4.760 -> 4.880, model saved
# Best mean return updated 4.880 -> 4.980, model saved
# Best mean return updated 4.980 -> 5.000, model saved
# Best mean return updated 5.000 -> 5.100, model saved
# Best mean return updated 5.100 -> 5.220, model saved
# Best mean return updated 5.220 -> 5.340, model saved
# Best mean return updated 5.340 -> 5.420, model saved
# Best mean return updated 5.420 -> 5.580, model saved
# Best mean return updated 5.580 -> 5.640, model saved
# Best mean return updated 5.640 -> 5.720, model saved
# step: 269062 | episode: 3750 | cur_return: 5.0000 | mean_return: 5.8000 | best_mean_return: 5.7200 | loss: 1.5527 | epsilon: 0.0531
# Best mean return updated 5.720 -> 5.800, model saved
# Best mean return updated 5.800 -> 5.860, model saved
# Best mean return updated 5.860 -> 5.880, model saved
# Best mean return updated 5.880 -> 5.920, model saved
# Best mean return updated 5.920 -> 6.000, model saved
# step: 279585 | episode: 3800 | cur_return: 1.0000 | mean_return: 5.3600 | best_mean_return: 6.0000 | loss: 0.4957 | epsilon: 0.0181
# Best mean return updated 6.000 -> 6.100, model saved
# Best mean return updated 6.100 -> 6.140, model saved
# Best mean return updated 6.140 -> 6.180, model saved
# Best mean return updated 6.180 -> 6.400, model saved
# Best mean return updated 6.400 -> 6.480, model saved
# Best mean return updated 6.480 -> 6.540, model saved
# Best mean return updated 6.540 -> 6.600, model saved
# Best mean return updated 6.600 -> 6.680, model saved
# Best mean return updated 6.680 -> 6.840, model saved
# Best mean return updated 6.840 -> 6.860, model saved
# step: 294350 | episode: 3850 | cur_return: 8.0000 | mean_return: 7.0000 | best_mean_return: 6.8600 | loss: 4.1643 | epsilon: 0.0100
# Best mean return updated 6.860 -> 7.000, model saved
# Best mean return updated 7.000 -> 7.020, model saved
# step: 305543 | episode: 3900 | cur_return: 5.0000 | mean_return: 5.7200 | best_mean_return: 7.0200 | loss: 0.8996 | epsilon: 0.0100
# step: 315794 | episode: 3950 | cur_return: 6.0000 | mean_return: 5.3600 | best_mean_return: 7.0200 | loss: 1.7202 | epsilon: 0.0100
# step: 328836 | episode: 4000 | cur_return: 2.0000 | mean_return: 6.2200 | best_mean_return: 7.0200 | loss: 1.0025 | epsilon: 0.0100
# step: 342445 | episode: 4050 | cur_return: 4.0000 | mean_return: 6.5400 | best_mean_return: 7.0200 | loss: 0.9929 | epsilon: 0.0100
# step: 353064 | episode: 4100 | cur_return: 10.0000 | mean_return: 6.0200 | best_mean_return: 7.0200 | loss: 2.1361 | epsilon: 0.0100
# Best mean return updated 7.020 -> 7.100, model saved
# Best mean return updated 7.100 -> 7.160, model saved
# Best mean return updated 7.160 -> 7.180, model saved
# Best mean return updated 7.180 -> 7.300, model saved
# step: 366498 | episode: 4150 | cur_return: 16.0000 | mean_return: 7.4200 | best_mean_return: 7.3000 | loss: 3.0600 | epsilon: 0.0100
# Best mean return updated 7.300 -> 7.420, model saved
# Best mean return updated 7.420 -> 7.580, model saved
# Best mean return updated 7.580 -> 7.620, model saved
# Best mean return updated 7.620 -> 7.640, model saved
# Best mean return updated 7.640 -> 7.840, model saved
# Best mean return updated 7.840 -> 7.860, model saved
# Best mean return updated 7.860 -> 7.880, model saved
# Best mean return updated 7.880 -> 7.980, model saved
# Best mean return updated 7.980 -> 8.160, model saved
# Best mean return updated 8.160 -> 8.180, model saved
# Best mean return updated 8.180 -> 8.280, model saved
# Best mean return updated 8.280 -> 8.320, model saved
# step: 378326 | episode: 4200 | cur_return: 5.0000 | mean_return: 7.5200 | best_mean_return: 8.3200 | loss: 0.9252 | epsilon: 0.0100
# Best mean return updated 8.320 -> 8.340, model saved
# Best mean return updated 8.340 -> 8.500, model saved
# Best mean return updated 8.500 -> 8.720, model saved
# Best mean return updated 8.720 -> 8.840, model saved
# Best mean return updated 8.840 -> 8.860, model saved
# Best mean return updated 8.860 -> 8.880, model saved
# Best mean return updated 8.880 -> 8.900, model saved
# Best mean return updated 8.900 -> 8.920, model saved
# Best mean return updated 8.920 -> 8.980, model saved
# step: 392339 | episode: 4250 | cur_return: 6.0000 | mean_return: 8.2400 | best_mean_return: 8.9800 | loss: 0.8512 | epsilon: 0.0100
# Best mean return updated 8.980 -> 9.000, model saved
# Best mean return updated 9.000 -> 9.020, model saved
# Best mean return updated 9.020 -> 9.040, model saved
# Best mean return updated 9.040 -> 9.260, model saved
# Best mean return updated 9.260 -> 9.300, model saved
# Best mean return updated 9.300 -> 9.440, model saved
# Best mean return updated 9.440 -> 9.600, model saved
# Best mean return updated 9.600 -> 9.680, model saved
# Best mean return updated 9.680 -> 9.780, model saved
# Best mean return updated 9.780 -> 9.920, model saved
# step: 408845 | episode: 4300 | cur_return: 8.0000 | mean_return: 9.9600 | best_mean_return: 9.9200 | loss: 1.2028 | epsilon: 0.0100
# Best mean return updated 9.920 -> 9.960, model saved
# Best mean return updated 9.960 -> 10.040, model saved
# Best mean return updated 10.040 -> 10.140, model saved
# Best mean return updated 10.140 -> 10.180, model saved
# Best mean return updated 10.180 -> 10.380, model saved
# Best mean return updated 10.380 -> 10.440, model saved
# Best mean return updated 10.440 -> 10.580, model saved
# Best mean return updated 10.580 -> 10.660, model saved
# Best mean return updated 10.660 -> 10.680, model saved
# step: 424530 | episode: 4350 | cur_return: 0.0000 | mean_return: 9.7000 | best_mean_return: 10.6800 | loss: 0.0847 | epsilon: 0.0100
# step: 438224 | episode: 4400 | cur_return: 7.0000 | mean_return: 9.1600 | best_mean_return: 10.6800 | loss: 0.9923 | epsilon: 0.0100
# step: 453241 | episode: 4450 | cur_return: 5.0000 | mean_return: 9.8400 | best_mean_return: 10.6800 | loss: 1.0806 | epsilon: 0.0100
# step: 468530 | episode: 4500 | cur_return: 5.0000 | mean_return: 9.6600 | best_mean_return: 10.6800 | loss: 0.7416 | epsilon: 0.0100
# step: 483054 | episode: 4550 | cur_return: 11.0000 | mean_return: 9.7600 | best_mean_return: 10.6800 | loss: 1.9400 | epsilon: 0.0100
# step: 500047 | episode: 4600 | cur_return: 12.0000 | mean_return: 10.5800 | best_mean_return: 10.6800 | loss: 1.6094 | epsilon: 0.0100
# Best mean return updated 10.680 -> 10.700, model saved
# Best mean return updated 10.700 -> 10.800, model saved
# Best mean return updated 10.800 -> 11.080, model saved
# Best mean return updated 11.080 -> 11.120, model saved
# Best mean return updated 11.120 -> 11.280, model saved
# Best mean return updated 11.280 -> 11.320, model saved
# Best mean return updated 11.320 -> 11.340, model saved
# Best mean return updated 11.340 -> 11.360, model saved
# Best mean return updated 11.360 -> 11.560, model saved
# Best mean return updated 11.560 -> 11.620, model saved
# Best mean return updated 11.620 -> 11.700, model saved
# Best mean return updated 11.700 -> 11.720, model saved
# step: 516596 | episode: 4650 | cur_return: 16.0000 | mean_return: 10.9600 | best_mean_return: 11.7200 | loss: 1.6444 | epsilon: 0.0100
# step: 532179 | episode: 4700 | cur_return: 4.0000 | mean_return: 9.4200 | best_mean_return: 11.7200 | loss: 0.7435 | epsilon: 0.0100
# Best mean return updated 11.720 -> 11.740, model saved
# Best mean return updated 11.740 -> 11.980, model saved
# step: 550214 | episode: 4750 | cur_return: 14.0000 | mean_return: 12.0000 | best_mean_return: 11.9800 | loss: 2.3295 | epsilon: 0.0100
# Best mean return updated 11.980 -> 12.000, model saved
# step: 566651 | episode: 4800 | cur_return: 14.0000 | mean_return: 10.4000 | best_mean_return: 12.0000 | loss: 1.2068 | epsilon: 0.0100
# step: 583832 | episode: 4850 | cur_return: 4.0000 | mean_return: 10.9200 | best_mean_return: 12.0000 | loss: 0.7146 | epsilon: 0.0100
# step: 600628 | episode: 4900 | cur_return: 15.0000 | mean_return: 11.2000 | best_mean_return: 12.0000 | loss: 2.4518 | epsilon: 0.0100
# step: 614935 | episode: 4950 | cur_return: 15.0000 | mean_return: 10.6400 | best_mean_return: 12.0000 | loss: 1.6317 | epsilon: 0.0100
# Best mean return updated 12.000 -> 12.140, model saved
# Best mean return updated 12.140 -> 12.160, model saved
# step: 631654 | episode: 5000 | cur_return: 20.0000 | mean_return: 12.2600 | best_mean_return: 12.1600 | loss: 1.2053 | epsilon: 0.0100
# Best mean return updated 12.160 -> 12.260, model saved
# Best mean return updated 12.260 -> 12.480, model saved
# Best mean return updated 12.480 -> 12.500, model saved
# Best mean return updated 12.500 -> 12.600, model saved
# Best mean return updated 12.600 -> 12.840, model saved
# Best mean return updated 12.840 -> 12.900, model saved
# step: 647597 | episode: 5050 | cur_return: 9.0000 | mean_return: 11.4000 | best_mean_return: 12.9000 | loss: 2.2548 | epsilon: 0.0100
# step: 666669 | episode: 5100 | cur_return: 9.0000 | mean_return: 9.0400 | best_mean_return: 12.9000 | loss: 1.3105 | epsilon: 0.0100
# step: 681633 | episode: 5150 | cur_return: 7.0000 | mean_return: 11.9400 | best_mean_return: 12.9000 | loss: 1.4845 | epsilon: 0.0100
# Best mean return updated 12.900 -> 13.140, model saved
# Best mean return updated 13.140 -> 13.360, model saved
# step: 697686 | episode: 5200 | cur_return: 14.0000 | mean_return: 12.5200 | best_mean_return: 13.3600 | loss: 2.6470 | epsilon: 0.0100
# step: 713054 | episode: 5250 | cur_return: 16.0000 | mean_return: 12.2000 | best_mean_return: 13.3600 | loss: 2.4905 | epsilon: 0.0100
# step: 728299 | episode: 5300 | cur_return: 3.0000 | mean_return: 11.6000 | best_mean_return: 13.3600 | loss: 1.0817 | epsilon: 0.0100
# step: 744191 | episode: 5350 | cur_return: 6.0000 | mean_return: 12.4400 | best_mean_return: 13.3600 | loss: 2.2419 | epsilon: 0.0100
# step: 758878 | episode: 5400 | cur_return: 11.0000 | mean_return: 11.5600 | best_mean_return: 13.3600 | loss: 1.9132 | epsilon: 0.0100
# step: 774143 | episode: 5450 | cur_return: 25.0000 | mean_return: 12.7600 | best_mean_return: 13.3600 | loss: 4.3424 | epsilon: 0.0100
# Best mean return updated 13.360 -> 13.560, model saved
# Best mean return updated 13.560 -> 13.580, model saved
# Best mean return updated 13.580 -> 13.740, model saved
# Best mean return updated 13.740 -> 13.780, model saved
# Best mean return updated 13.780 -> 14.060, model saved
# Best mean return updated 14.060 -> 14.200, model saved
# Best mean return updated 14.200 -> 14.700, model saved
# Best mean return updated 14.700 -> 14.900, model saved
# Best mean return updated 14.900 -> 15.080, model saved
# Best mean return updated 15.080 -> 15.220, model saved
# Best mean return updated 15.220 -> 15.580, model saved
# step: 790273 | episode: 5500 | cur_return: 22.0000 | mean_return: 15.4800 | best_mean_return: 15.5800 | loss: 2.7163 | epsilon: 0.0100
# Best mean return updated 15.580 -> 15.900, model saved
# Best mean return updated 15.900 -> 16.100, model saved
# Best mean return updated 16.100 -> 16.220, model saved
# Best mean return updated 16.220 -> 16.260, model saved
# Best mean return updated 16.260 -> 16.560, model saved
# Best mean return updated 16.560 -> 16.600, model saved
# Best mean return updated 16.600 -> 16.720, model saved
# Best mean return updated 16.720 -> 16.880, model saved
# Best mean return updated 16.880 -> 17.000, model saved
# Best mean return updated 17.000 -> 17.360, model saved
# Best mean return updated 17.360 -> 17.400, model saved
# Best mean return updated 17.400 -> 17.640, model saved
# Best mean return updated 17.640 -> 18.100, model saved
# Best mean return updated 18.100 -> 18.180, model saved
# Best mean return updated 18.180 -> 18.540, model saved
# step: 806979 | episode: 5550 | cur_return: 7.0000 | mean_return: 16.3400 | best_mean_return: 18.5400 | loss: 1.3975 | epsilon: 0.0100
# step: 825284 | episode: 5600 | cur_return: 13.0000 | mean_return: 16.5000 | best_mean_return: 18.5400 | loss: 3.2767 | epsilon: 0.0100
# Best mean return updated 18.540 -> 19.480, model saved
# Best mean return updated 19.480 -> 19.680, model saved
# Best mean return updated 19.680 -> 19.780, model saved
# Best mean return updated 19.780 -> 20.420, model saved
# step: 844579 | episode: 5650 | cur_return: 16.0000 | mean_return: 15.9600 | best_mean_return: 20.4200 | loss: 3.2429 | epsilon: 0.0100
# step: 862085 | episode: 5700 | cur_return: 1.0000 | mean_return: 15.6400 | best_mean_return: 20.4200 | loss: 0.6056 | epsilon: 0.0100
# step: 880742 | episode: 5750 | cur_return: 29.0000 | mean_return: 18.5000 | best_mean_return: 20.4200 | loss: 5.6148 | epsilon: 0.0100
# Best mean return updated 20.420 -> 20.800, model saved
# Best mean return updated 20.800 -> 20.960, model saved
# step: 899332 | episode: 5800 | cur_return: 20.0000 | mean_return: 18.6600 | best_mean_return: 20.9600 | loss: 4.5075 | epsilon: 0.0100
# step: 917827 | episode: 5850 | cur_return: 1.0000 | mean_return: 20.5600 | best_mean_return: 20.9600 | loss: 0.4726 | epsilon: 0.0100
# Best mean return updated 20.960 -> 21.160, model saved
# Best mean return updated 21.160 -> 22.160, model saved
# Best mean return updated 22.160 -> 23.360, model saved
# Best mean return updated 23.360 -> 24.200, model saved
# Best mean return updated 24.200 -> 25.400, model saved
# Best mean return updated 25.400 -> 25.600, model saved
# Best mean return updated 25.600 -> 26.300, model saved
# Best mean return updated 26.300 -> 26.920, model saved
# step: 934373 | episode: 5900 | cur_return: 3.0000 | mean_return: 25.3600 | best_mean_return: 26.9200 | loss: 2.9662 | epsilon: 0.0100
# Best mean return updated 26.920 -> 27.200, model saved
# Best mean return updated 27.200 -> 28.360, model saved
# step: 954806 | episode: 5950 | cur_return: 7.0000 | mean_return: 26.3000 | best_mean_return: 28.3600 | loss: 2.6792 | epsilon: 0.0100
# step: 974059 | episode: 6000 | cur_return: 74.0000 | mean_return: 21.2400 | best_mean_return: 28.3600 | loss: 7.5681 | epsilon: 0.0100
# step: 993551 | episode: 6050 | cur_return: 22.0000 | mean_return: 23.0800 | best_mean_return: 28.3600 | loss: 7.7621 | epsilon: 0.0100
# step: 1009442 | episode: 6100 | cur_return: 4.0000 | mean_return: 14.2400 | best_mean_return: 28.3600 | loss: 2.1435 | epsilon: 0.0100
# step: 1026374 | episode: 6150 | cur_return: 9.0000 | mean_return: 26.7200 | best_mean_return: 28.3600 | loss: 7.2047 | epsilon: 0.0100
# step: 1044010 | episode: 6200 | cur_return: 66.0000 | mean_return: 21.5800 | best_mean_return: 28.3600 | loss: 6.9526 | epsilon: 0.0100
# step: 1062139 | episode: 6250 | cur_return: 65.0000 | mean_return: 17.5000 | best_mean_return: 28.3600 | loss: 12.3632 | epsilon: 0.0100
# step: 1078854 | episode: 6300 | cur_return: 24.0000 | mean_return: 21.8000 | best_mean_return: 28.3600 | loss: 4.8363 | epsilon: 0.0100
# step: 1094781 | episode: 6350 | cur_return: 7.0000 | mean_return: 22.0600 | best_mean_return: 28.3600 | loss: 3.8162 | epsilon: 0.0100
# step: 1112435 | episode: 6400 | cur_return: 14.0000 | mean_return: 23.3600 | best_mean_return: 28.3600 | loss: 10.4454 | epsilon: 0.0100
# Best mean return updated 28.360 -> 31.520, model saved
# Best mean return updated 31.520 -> 32.460, model saved
# Best mean return updated 32.460 -> 32.600, model saved
# Best mean return updated 32.600 -> 33.000, model saved
# Best mean return updated 33.000 -> 33.380, model saved
# step: 1131170 | episode: 6450 | cur_return: 75.0000 | mean_return: 32.9400 | best_mean_return: 33.3800 | loss: 14.3184 | epsilon: 0.0100
# Best mean return updated 33.380 -> 33.440, model saved
# Best mean return updated 33.440 -> 33.700, model saved
# step: 1150597 | episode: 6500 | cur_return: 3.0000 | mean_return: 31.8800 | best_mean_return: 33.7000 | loss: 3.8354 | epsilon: 0.0100
# step: 1167242 | episode: 6550 | cur_return: 14.0000 | mean_return: 21.1200 | best_mean_return: 33.7000 | loss: 11.1483 | epsilon: 0.0100
# Best mean return updated 33.700 -> 37.260, model saved
# step: 1182921 | episode: 6600 | cur_return: 32.0000 | mean_return: 32.8200 | best_mean_return: 37.2600 | loss: 18.7692 | epsilon: 0.0100
# step: 1208363 | episode: 6650 | cur_return: 46.0000 | mean_return: 34.0800 | best_mean_return: 37.2600 | loss: 24.7676 | epsilon: 0.0100
# step: 1223978 | episode: 6700 | cur_return: 6.0000 | mean_return: 24.5400 | best_mean_return: 37.2600 | loss: 8.3930 | epsilon: 0.0100
# step: 1241211 | episode: 6750 | cur_return: 48.0000 | mean_return: 32.7200 | best_mean_return: 37.2600 | loss: 26.4722 | epsilon: 0.0100
# Best mean return updated 37.260 -> 40.980, model saved
# Best mean return updated 40.980 -> 41.220, model saved
# Best mean return updated 41.220 -> 41.520, model saved
# Best mean return updated 41.520 -> 41.840, model saved
# Best mean return updated 41.840 -> 42.760, model saved
# Best mean return updated 42.760 -> 43.600, model saved
# Best mean return updated 43.600 -> 44.040, model saved
# step: 1260012 | episode: 6800 | cur_return: 55.0000 | mean_return: 44.1800 | best_mean_return: 44.0400 | loss: 29.1116 | epsilon: 0.0100
# Best mean return updated 44.040 -> 44.180, model saved
# Best mean return updated 44.180 -> 48.280, model saved
# Best mean return updated 48.280 -> 48.320, model saved
# Best mean return updated 48.320 -> 48.340, model saved
# Best mean return updated 48.340 -> 48.900, model saved
# Best mean return updated 48.900 -> 52.680, model saved
# Best mean return updated 52.680 -> 53.220, model saved
# step: 1278964 | episode: 6850 | cur_return: 50.0000 | mean_return: 49.2200 | best_mean_return: 53.2200 | loss: 32.3353 | epsilon: 0.0100
# Best mean return updated 53.220 -> 56.980, model saved
# Best mean return updated 56.980 -> 58.580, model saved
# Best mean return updated 58.580 -> 62.680, model saved
# Best mean return updated 62.680 -> 64.060, model saved
# Best mean return updated 64.060 -> 66.620, model saved
# Best mean return updated 66.620 -> 68.760, model saved
# Best mean return updated 68.760 -> 69.440, model saved
# Best mean return updated 69.440 -> 69.960, model saved
# Best mean return updated 69.960 -> 71.040, model saved
# Best mean return updated 71.040 -> 72.920, model saved
# Best mean return updated 72.920 -> 73.620, model saved
# Best mean return updated 73.620 -> 74.700, model saved
# Best mean return updated 74.700 -> 74.920, model saved
# Best mean return updated 74.920 -> 75.420, model saved
# step: 1300132 | episode: 6900 | cur_return: 87.0000 | mean_return: 76.1600 | best_mean_return: 75.4200 | loss: 61.9928 | epsilon: 0.0100
# Best mean return updated 75.420 -> 76.160, model saved
# Best mean return updated 76.160 -> 76.280, model saved
# Best mean return updated 76.280 -> 76.820, model saved
# Best mean return updated 76.820 -> 77.900, model saved
# Best mean return updated 77.900 -> 77.920, model saved
# Best mean return updated 77.920 -> 80.960, model saved
# Best mean return updated 80.960 -> 81.780, model saved
# step: 1319729 | episode: 6950 | cur_return: 4.0000 | mean_return: 58.2400 | best_mean_return: 81.7800 | loss: 16.8782 | epsilon: 0.0100
# step: 1337701 | episode: 7000 | cur_return: 105.0000 | mean_return: 39.8200 | best_mean_return: 81.7800 | loss: 76.9864 | epsilon: 0.0100
# step: 1359804 | episode: 7050 | cur_return: 56.0000 | mean_return: 60.2400 | best_mean_return: 81.7800 | loss: 53.9129 | epsilon: 0.0100
# step: 1379263 | episode: 7100 | cur_return: 51.0000 | mean_return: 56.6000 | best_mean_return: 81.7800 | loss: 41.2446 | epsilon: 0.0100
# step: 1398098 | episode: 7150 | cur_return: 56.0000 | mean_return: 78.2400 | best_mean_return: 81.7800 | loss: 51.6750 | epsilon: 0.0100
# Best mean return updated 81.780 -> 82.700, model saved
# Best mean return updated 82.700 -> 86.100, model saved
# Best mean return updated 86.100 -> 88.940, model saved
# Best mean return updated 88.940 -> 90.000, model saved
# Best mean return updated 90.000 -> 93.580, model saved
# Best mean return updated 93.580 -> 95.200, model saved
# Best mean return updated 95.200 -> 96.100, model saved
# Best mean return updated 96.100 -> 96.140, model saved
# Best mean return updated 96.140 -> 100.000, model saved
# Best mean return updated 100.000 -> 100.720, model saved
# Best mean return updated 100.720 -> 101.920, model saved
# Best mean return updated 101.920 -> 107.320, model saved
# Best mean return updated 107.320 -> 112.500, model saved
# step: 1419622 | episode: 7200 | cur_return: 4.0000 | mean_return: 99.4400 | best_mean_return: 112.5000 | loss: 23.3145 | epsilon: 0.0100
# step: 1438729 | episode: 7250 | cur_return: 1.0000 | mean_return: 80.9400 | best_mean_return: 112.5000 | loss: 24.6223 | epsilon: 0.0100
# step: 1455266 | episode: 7300 | cur_return: 270.0000 | mean_return: 66.8400 | best_mean_return: 112.5000 | loss: 106.4866 | epsilon: 0.0100
# step: 1474929 | episode: 7350 | cur_return: 24.0000 | mean_return: 83.3800 | best_mean_return: 112.5000 | loss: 35.1884 | epsilon: 0.0100
# step: 1494132 | episode: 7400 | cur_return: 2.0000 | mean_return: 88.2000 | best_mean_return: 112.5000 | loss: 20.9117 | epsilon: 0.0100
# step: 1515834 | episode: 7450 | cur_return: 273.0000 | mean_return: 94.9000 | best_mean_return: 112.5000 | loss: 92.7701 | epsilon: 0.0100
# Best mean return updated 112.500 -> 114.460, model saved
# Best mean return updated 114.460 -> 117.640, model saved
# Best mean return updated 117.640 -> 117.980, model saved
# Best mean return updated 117.980 -> 119.580, model saved
# Best mean return updated 119.580 -> 121.940, model saved
# Best mean return updated 121.940 -> 126.440, model saved
# Best mean return updated 126.440 -> 128.040, model saved
# Best mean return updated 128.040 -> 131.260, model saved
# Best mean return updated 131.260 -> 133.460, model saved
# Best mean return updated 133.460 -> 136.420, model saved
# Best mean return updated 136.420 -> 140.400, model saved
# Best mean return updated 140.400 -> 143.960, model saved
# Best mean return updated 143.960 -> 146.480, model saved
# Best mean return updated 146.480 -> 149.440, model saved
# Best mean return updated 149.440 -> 151.580, model saved
# Best mean return updated 151.580 -> 154.400, model saved
# Best mean return updated 154.400 -> 155.400, model saved
# step: 1541622 | episode: 7500 | cur_return: 247.0000 | mean_return: 144.9800 | best_mean_return: 155.4000 | loss: 114.7742 | epsilon: 0.0100
# step: 1564387 | episode: 7550 | cur_return: 3.0000 | mean_return: 87.4400 | best_mean_return: 155.4000 | loss: 63.9167 | epsilon: 0.0100
# step: 1584599 | episode: 7600 | cur_return: 0.0000 | mean_return: 76.7400 | best_mean_return: 155.4000 | loss: 5.6806 | epsilon: 0.0100
# step: 1605239 | episode: 7650 | cur_return: 19.0000 | mean_return: 113.0800 | best_mean_return: 155.4000 | loss: 44.5112 | epsilon: 0.0100
# step: 1622268 | episode: 7700 | cur_return: 31.0000 | mean_return: 80.0400 | best_mean_return: 155.4000 | loss: 46.3764 | epsilon: 0.0100
# step: 1642019 | episode: 7750 | cur_return: 19.0000 | mean_return: 86.1800 | best_mean_return: 155.4000 | loss: 30.6458 | epsilon: 0.0100
# step: 1663234 | episode: 7800 | cur_return: 5.0000 | mean_return: 120.3600 | best_mean_return: 155.4000 | loss: 23.4677 | epsilon: 0.0100
# step: 1688366 | episode: 7850 | cur_return: 19.0000 | mean_return: 151.6600 | best_mean_return: 155.4000 | loss: 24.6387 | epsilon: 0.0100
# Best mean return updated 155.400 -> 157.680, model saved
# step: 1710620 | episode: 7900 | cur_return: 214.0000 | mean_return: 131.4000 | best_mean_return: 157.6800 | loss: 79.8939 | epsilon: 0.0100
# step: 1730770 | episode: 7950 | cur_return: 214.0000 | mean_return: 121.5400 | best_mean_return: 157.6800 | loss: 71.1093 | epsilon: 0.0100
# Best mean return updated 157.680 -> 159.900, model saved
# Best mean return updated 159.900 -> 163.420, model saved
# Best mean return updated 163.420 -> 169.800, model saved
# Best mean return updated 169.800 -> 169.880, model saved
# Best mean return updated 169.880 -> 174.800, model saved
# step: 1755114 | episode: 8000 | cur_return: 19.0000 | mean_return: 158.4000 | best_mean_return: 174.8000 | loss: 30.7793 | epsilon: 0.0100
# Best mean return updated 174.800 -> 178.020, model saved
# Best mean return updated 178.020 -> 184.480, model saved
# Best mean return updated 184.480 -> 185.680, model saved
# Best mean return updated 185.680 -> 192.140, model saved
# step: 1785695 | episode: 8050 | cur_return: 6.0000 | mean_return: 191.8800 | best_mean_return: 192.1400 | loss: 57.0250 | epsilon: 0.0100
# Best mean return updated 192.140 -> 192.300, model saved
# Best mean return updated 192.300 -> 197.540, model saved
# Best mean return updated 197.540 -> 200.200, model saved
# Solved!
# WorkingTime[DuelingDQNAgent]: 10725.1591 sec

# %%
fig, ax = rl_util.init_2d_figure("Reward")
rl_util.plot_graph(
    ax,
    episode_returns,
    title="reward",
    ylabel="reward",
    save_dir_name=save_dir,
    is_save=True,
)
rl_util.show_figure()
fig, ax = rl_util.init_2d_figure("Loss")
rl_util.plot_graph(
    ax, episode_losses, title="loss", ylabel="loss", save_dir_name=save_dir, is_save=True
)
rl_util.show_figure()
# Out:
# Save result/DuelingDQN/atari/reward_2023_07_05_06_36_12.png
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 13
#      10 rl_util.show_figure()
#      11 fig, ax = rl_util.init_2d_figure("Loss")
#      12 rl_util.plot_graph(
# ---> 13     ax, episode_losses, title="loss", ylabel="loss", save_dir_name=save_dir, is_save=True
#      14 )
#      15 rl_util.show_figure()
#
# NameError: name 'episode_losses' is not defined

# %%
env_name = "BreakoutNoFrameskip-v4"
env = gym.make(env_name, render_mode="human")
env = gym.wrappers.AtariPreprocessing(
    env=env, 
    terminal_on_life_loss=True, 
    grayscale_obs=True, 
    scale_obs=False,
    noop_max=30)
env = gym.wrappers.FrameStack(env, num_stack=4)

config = rl_util.create_config()
config["print_frequency"] = 50
config["mean_reward_bound"] = 200

test_agent = DuelingDQNAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=True,
    config=config,
)

# file_name = save_dir + "CartPole-v1_mean_score.pt"
save_model_name = "/home/railab/Workspace/2023-RL-Seminar/notebooks/result/DuelingDQN/atari/BreakoutNoFrameskip-v4_2023_07_05_02_46_49.pt"
test_agent.policy_network.load_state_dict(torch.load(save_model_name))

for i_episode in range(1):
    state, _ = env.reset()
    test_reward = 0
    while True:
        env.render()
        action = test_agent.select_action(state, 0.)
        next_state, reward, terminated, truncated, _ = env.step(action)
        test_reward += reward
        state = next_state
        done = terminated or truncated
        if done:
            break
    print(f"{i_episode} episode Total Reward: {test_reward}")
env.close()
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Model Initializing... An input shape is (4, 84, 84)
# Model Initializing... An input shape is (4, 84, 84)
# /home/railab/anaconda3/envs/conda_seminar/lib/python3.8/site-packages/gymnasium/utils/passive_env_checker.py:364: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
