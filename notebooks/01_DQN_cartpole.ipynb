# %%
import gymnasium as gym
import torch
import numpy as np
import time
from src.utils.util import ShellColor as sc

print(f"{sc.COLOR_PURPLE}Gym version:{sc.ENDC} {gym.__version__}")
print(f"{sc.COLOR_PURPLE}Pytorch version:{sc.ENDC} {torch.__version__}")

from src.agents.dqn_agent import DQNAgent
from src.utils import util as rl_util
# Out:
# Gym version: 0.27.0
# Pytorch version: 1.12.0+cu113

# %%
env_name = "CartPole-v1"
env = gym.make(env_name)
rl_util.print_env_info(env=env)
# Out:
# ============ Env Info ===========
# Env id: CartPole-v1
# Observation space size: (4,)
# Action space size: 2
# =================================

# %%
config = rl_util.create_config()
config["batch_size"] = 32
config["buffer_size"] = 30000
config["gamma"] = 0.99
config["update_frequency"] = 4
config["lr"] = 0.001
config["print_frequency"] = 5
config["mean_reward_bound"] = 490

# %%
# wandb.init(project="DQN-cartpole", config=config)

# %%
agent = DQNAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=False,
    config=config,
)

print(agent.config)
print(type(agent.memory))
# Out:
# ========== Config Info ==========
# n_episodes: 2000
# max_steps: 2000000
# batch_size: 32
# gamma: 0.99
# lr: 0.001
# start_training_step: 10000
# learning_frequency: 1
# epsilon_start: 0.95
# epsilon_end: 0.01
# epsilon_decay: 300000.0
# seed: 0
# target_update_frequency: 1000
# buffer_size: 30000
# device: cuda:0
# mean_reward_bound: 10
# print_frequency: 5
# =================================
# <class 'src.commons.memory.replay_memory.ReplayMemory'>

# %%
save_dir = "result/DQN/cartpole/"
rl_util.create_directory(save_dir)
current_time = rl_util.get_current_time_string()
save_model_name = save_dir + env_name + "_" + current_time+".pt"

# %%
obs, _ =  env.reset()
episode_returns = []
episode_return = 0
episode_losses = []
episode_loss = 0
episode = 0
best_mean_return = -10000
is_start_train = True
cnt = 0 
epsilon = agent.config.epsilon_start

start_time = time.time()
for t in range(agent.config.max_steps):
    cnt += 1
    action = agent.select_action(obs, epsilon)
    next_obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    agent.store_transition(obs, action, reward, next_obs, done)
    episode_return += reward
    
    if len(agent.memory.replay_buffer) > 1000:
        if is_start_train:
            print(f"Start Training at timestep {t}...")
            is_start_train = False
        episode_loss += agent.update()
        agent.soft_update_target_network()

    if done:
        epsilon = max(agent.config.epsilon_end, epsilon - 0.001)
        obs, _ = env.reset()
        episode += 1
        episode_loss /= cnt
        cnt = 0
        episode_returns.append(episode_return)
        episode_losses.append(episode_loss)
        mean_episode_return = np.mean(episode_returns[-agent.config.print_frequency:])
        mean_episode_loss = np.mean(episode_losses[-agent.config.print_frequency:])
        
        if episode % agent.config.print_frequency == 0:
            print(
                f"episode: {episode} | cur_reward: {episode_return:.4f} | loss: {episode_loss:.4f} | epsilon: {epsilon:.4f}"
            )

        if best_mean_return < mean_episode_return:
            torch.save(agent.policy_network.state_dict(), save_model_name)
            print(f"Best mean return updated {best_mean_return:.3f} -> {mean_episode_return:.3f}, model saved")
            best_mean_return = mean_episode_return
            if mean_episode_return > agent.config.mean_reward_bound:
                print(f"Solved!")
                break
                
        episode_return = 0
        episode_loss = 0
    else:
        obs = next_obs
end_time = time.time()
print(f"WorkingTime[{DQNAgent.__name__}]: {end_time-start_time:.4f} sec\n")
# Out:
# Best mean return updated -10000.000 -> 14.000, model saved
# Best mean return updated 14.000 -> 24.000, model saved
# episode: 5 | cur_reward: 12.0000 | loss: 0.0000 | epsilon: 0.9450
# episode: 10 | cur_reward: 12.0000 | loss: 0.0000 | epsilon: 0.9400
# episode: 15 | cur_reward: 15.0000 | loss: 0.0000 | epsilon: 0.9350
# episode: 20 | cur_reward: 9.0000 | loss: 0.0000 | epsilon: 0.9300
# Best mean return updated 24.000 -> 26.600, model saved
# episode: 25 | cur_reward: 15.0000 | loss: 0.0000 | epsilon: 0.9250
# Best mean return updated 26.600 -> 27.800, model saved
# Best mean return updated 27.800 -> 29.200, model saved
# Best mean return updated 29.200 -> 34.200, model saved
# episode: 30 | cur_reward: 13.0000 | loss: 0.0000 | epsilon: 0.9200
# episode: 35 | cur_reward: 17.0000 | loss: 0.0000 | epsilon: 0.9150
# episode: 40 | cur_reward: 10.0000 | loss: 0.0000 | epsilon: 0.9100
# episode: 45 | cur_reward: 21.0000 | loss: 0.0000 | epsilon: 0.9050
# Start Training at timestep 1000...
# episode: 50 | cur_reward: 33.0000 | loss: 0.2008 | epsilon: 0.9000
# episode: 55 | cur_reward: 11.0000 | loss: 0.0401 | epsilon: 0.8950
# episode: 60 | cur_reward: 15.0000 | loss: 0.0739 | epsilon: 0.8900
# episode: 65 | cur_reward: 22.0000 | loss: 0.1832 | epsilon: 0.8850
# episode: 70 | cur_reward: 18.0000 | loss: 0.3642 | epsilon: 0.8800
# episode: 75 | cur_reward: 19.0000 | loss: 0.4273 | epsilon: 0.8750
# episode: 80 | cur_reward: 29.0000 | loss: 0.4245 | epsilon: 0.8700
# episode: 85 | cur_reward: 33.0000 | loss: 0.4496 | epsilon: 0.8650
# episode: 90 | cur_reward: 55.0000 | loss: 0.5769 | epsilon: 0.8600
# Best mean return updated 34.200 -> 35.400, model saved
# episode: 95 | cur_reward: 20.0000 | loss: 0.5058 | epsilon: 0.8550
# Best mean return updated 35.400 -> 36.000, model saved
# Best mean return updated 36.000 -> 37.800, model saved
# Best mean return updated 37.800 -> 39.600, model saved
# episode: 100 | cur_reward: 67.0000 | loss: 0.6639 | epsilon: 0.8500
# Best mean return updated 39.600 -> 49.000, model saved
# Best mean return updated 49.000 -> 54.400, model saved
# episode: 105 | cur_reward: 74.0000 | loss: 0.7684 | epsilon: 0.8450
# Best mean return updated 54.400 -> 55.800, model saved
# Best mean return updated 55.800 -> 63.600, model saved
# Best mean return updated 63.600 -> 66.800, model saved
# Best mean return updated 66.800 -> 67.000, model saved
# episode: 110 | cur_reward: 51.0000 | loss: 1.0142 | epsilon: 0.8400
# episode: 115 | cur_reward: 79.0000 | loss: 1.1386 | epsilon: 0.8350
# episode: 120 | cur_reward: 51.0000 | loss: 1.7316 | epsilon: 0.8300
# episode: 125 | cur_reward: 23.0000 | loss: 1.7034 | epsilon: 0.8250
# episode: 130 | cur_reward: 67.0000 | loss: 2.3482 | epsilon: 0.8200
# episode: 135 | cur_reward: 21.0000 | loss: 5.8915 | epsilon: 0.8150
# episode: 140 | cur_reward: 47.0000 | loss: 2.8400 | epsilon: 0.8100
# episode: 835 | cur_reward: 95.0000 | loss: 12.9337 | epsilon: 0.1150
# episode: 840 | cur_reward: 149.0000 | loss: 11.4573 | epsilon: 0.1100
# episode: 845 | cur_reward: 61.0000 | loss: 8.6047 | epsilon: 0.1050
# episode: 850 | cur_reward: 93.0000 | loss: 24.9561 | epsilon: 0.1000
# episode: 855 | cur_reward: 14.0000 | loss: 54.0697 | epsilon: 0.0950
# episode: 860 | cur_reward: 500.0000 | loss: 24.0888 | epsilon: 0.0900
# episode: 865 | cur_reward: 269.0000 | loss: 28.1770 | epsilon: 0.0850
# episode: 870 | cur_reward: 500.0000 | loss: 24.6077 | epsilon: 0.0800
# episode: 875 | cur_reward: 14.0000 | loss: 48.4201 | epsilon: 0.0750
# episode: 880 | cur_reward: 21.0000 | loss: 2.7090 | epsilon: 0.0700
# episode: 885 | cur_reward: 317.0000 | loss: 18.8823 | epsilon: 0.0650
# episode: 890 | cur_reward: 66.0000 | loss: 15.4438 | epsilon: 0.0600
# episode: 895 | cur_reward: 335.0000 | loss: 19.0369 | epsilon: 0.0550
# episode: 900 | cur_reward: 483.0000 | loss: 28.8312 | epsilon: 0.0500
# episode: 905 | cur_reward: 417.0000 | loss: 14.6067 | epsilon: 0.0450
# episode: 910 | cur_reward: 205.0000 | loss: 31.3648 | epsilon: 0.0400
# episode: 915 | cur_reward: 500.0000 | loss: 15.6007 | epsilon: 0.0350
# episode: 920 | cur_reward: 31.0000 | loss: 26.1719 | epsilon: 0.0300
# episode: 925 | cur_reward: 214.0000 | loss: 25.1933 | epsilon: 0.0250
# episode: 930 | cur_reward: 224.0000 | loss: 15.0367 | epsilon: 0.0200
# episode: 935 | cur_reward: 97.0000 | loss: 27.2066 | epsilon: 0.0150
# episode: 940 | cur_reward: 345.0000 | loss: 30.1687 | epsilon: 0.0100
# episode: 945 | cur_reward: 174.0000 | loss: 25.6049 | epsilon: 0.0100
# episode: 950 | cur_reward: 500.0000 | loss: 18.8720 | epsilon: 0.0100
# Best mean return updated 469.000 -> 500.000, model saved
# Solved!

# %%
fig, ax = rl_util.init_2d_figure("Reward")
rl_util.plot_graph(
    ax,
    episode_returns,
    title="reward",
    ylabel="reward",
    save_dir_name=save_dir,
    is_save=True,
)
rl_util.show_figure()
fig, ax = rl_util.init_2d_figure("Loss")
rl_util.plot_graph(
    ax, episode_losses, title="loss", ylabel="loss", save_dir_name=save_dir, is_save=True
)
rl_util.show_figure()
# Out:
# Save result/DQN/cartpole/reward_2023_02_19_12_33_41.png
# Save result/DQN/cartpole/loss_2023_02_19_12_33_41.png

# %%
env = gym.make(env_name, render_mode="human")

test_agent = DQNAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=False,
    config=config
)

# file_name = save_dir + "CartPole-v1_mean_score.pt"
test_agent.policy_network.load_state_dict(torch.load(save_model_name))

for i_episode in range(1):
    state, _ = env.reset()
    test_reward = 0
    while True:
        env.render()
        action = test_agent.select_action(state, 0.)
        next_state, reward, terminated, truncated, _ = env.step(action)
        test_reward += reward
        state = next_state
        done = terminated or truncated
        if done:
            break
    print(f"{i_episode} episode Total Reward: {test_reward}")
env.close()
# Out:
# 0 episode Total Reward: 500.0
