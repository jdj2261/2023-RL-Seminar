# %%
import gymnasium as gym
import torch
import numpy as np
import wandb
from collections import deque
from src.utils.util import ShellColor as sc

print(f"{sc.COLOR_PURPLE}Gym version:{sc.ENDC} {gym.__version__}")
print(f"{sc.COLOR_PURPLE}Pytorch version:{sc.ENDC} {torch.__version__}")

from src.agents.dqn_agent import DQNAgent
from src.utils import util as rl_util
# Out:
# Gym version: 0.27.0
# Pytorch version: 1.12.0+cu113

# %%
env_name = "CartPole-v1"
env = gym.make(env_name)
rl_util.print_env_info(env=env)
# Out:
# ============ Env Info ===========
# Env id: CartPole-v1
# Observation space size: (4,)
# Action space size: 2
# =================================

# %%
config = rl_util.create_config()
config["batch_size"] = 32
config["buffer_size"] = 20000
config["gamma"] = 0.99
config["learning_frequency"] = 4
config["target_update_frequency"] = 4
config["lr"] = 1e-4
config["replay_start_size"] = 1000
config["mean_reward_bound"] = 490
# config["buffer_type"] = "priority"
config["learning_starts"] = 1000

# %%
# wandb.init(project="DQN-PER-cartpole", config=config)

# %%
agent = DQNAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=False,
    config=config,
    use_double_dqn=True
)

print(agent.config)
print(type(agent.memory))
# Out:
# Double DQN Agent
# ========== Config Info ==========
# env: PongNoFrameskip-v4
# num_steps: 1000000
# batch_size: 32
# gamma: 0.99
# lr: 0.0001
# learning_starts: 1000
# learning_frequency: 4
# epsilon_start: 1
# epsilon_end: 0.01
# epsilon_decay: 100000
# seed: 0
# target_update_frequency: 4
# buffer_type: uniform
# buffer_size: 20000
# device: cuda:0
# mean_reward_bound: 490
# print_frequency: 10
# =================================
# <class 'src.commons.memory.replay_memory.ReplayMemory'>

# %%
save_dir = "result/DQN/per/"
rl_util.create_directory(save_dir)
save_model_name = save_dir + env_name + "_mean_score.pt"

# %%
state, _ = env.reset()
episode_rewards = [0.0]
best_mean_reward = -10000
for t in range(agent.config.num_steps):
    fraction = min(1.0, float(t) / agent.config.epsilon_decay)
    eps_threshold = agent.config.epsilon_start + fraction * \
        (agent.config.epsilon_end - agent.config.epsilon_start)
    # sample = random.random()
    action = agent.select_action(state, eps_threshold)
    next_state, reward, done, _, info = env.step(action)
    agent.store_transition(state, action, reward, next_state, float(done))
    state = next_state

    episode_rewards[-1] += reward
    if done:
        state, _ = env.reset()
        episode_rewards.append(0.0)

    if t > agent.config.learning_starts and t % agent.config.learning_frequency == 0:
        agent.update()

    if t > agent.config.learning_starts and t % agent.config.target_update_frequency == 0:
        agent.update_target_network()

    num_episodes = len(episode_rewards)

    if done and agent.config.print_frequency is not None and len(episode_rewards) % agent.config.print_frequency == 0:
        mean_100ep_reward = round(np.mean(episode_rewards[-101:-1]), 1)
        print("********************************************************")
        print("steps: {}".format(t))
        print("episodes: {}".format(num_episodes))
        print("mean 100 episode reward: {}".format(mean_100ep_reward))
        print("% time spent exploring: {}".format(int(100 * eps_threshold)))
        print("********************************************************")
        # wandb.log({
        #     "episode": num_episodes,
        #     "mean reward": mean_100ep_reward,
        #     "epsilon": eps_threshold
        # })
        if best_mean_reward < mean_100ep_reward:
            torch.save(agent.policy_network.state_dict(), save_model_name)
            print(f"Best mean reward updated {best_mean_reward:.3f} -> {mean_100ep_reward:.3f}, model saved")
            best_mean_reward = mean_100ep_reward
            if mean_100ep_reward > agent.config.mean_reward_bound:
                print(f"Solved!")
                break
            # else:
            #     if num_episodes > 1000:
            #         break
# Out:
# ********************************************************
# steps: 160
# episodes: 10
# mean 100 episode reward: 17.9
# % time spent exploring: 99
# ********************************************************
# Best mean reward updated -10000.000 -> 17.900, model saved
# ********************************************************
# steps: 420
# episodes: 20
# mean 100 episode reward: 22.2
# % time spent exploring: 99
# ********************************************************
# Best mean reward updated 17.900 -> 22.200, model saved
# ********************************************************
# steps: 658
# episodes: 30
# mean 100 episode reward: 22.7
# % time spent exploring: 99
# ********************************************************
# Best mean reward updated 22.200 -> 22.700, model saved
# ********************************************************
# steps: 873
# episodes: 40
# mean 100 episode reward: 22.4
# % time spent exploring: 99
# ********************************************************
# ********************************************************
# steps: 1083
# episodes: 50
# mean 100 episode reward: 22.1
# % time spent exploring: 98
# ********************************************************
# ********************************************************
# steps: 1290
# episodes: 60
# mean 100 episode reward: 21.9
# % time spent exploring: 98
# ********************************************************
# ********************************************************
# steps: 1535
# episodes: 70
# mean 100 episode reward: 22.3
# % time spent exploring: 98
# ********************************************************
# ********************************************************
# steps: 1731
# episodes: 80
# mean 100 episode reward: 21.9
# % time spent exploring: 98
# ********************************************************
# ********************************************************
# steps: 2013
# episodes: 90
# mean 100 episode reward: 22.6
# % time spent exploring: 98
# ********************************************************
# ********************************************************
# steps: 2234
# episodes: 100
# mean 100 episode reward: 22.6
# % time spent exploring: 97
# ********************************************************
# ********************************************************
# steps: 2574
# episodes: 110
# mean 100 episode reward: 24.1
# % time spent exploring: 97
# ********************************************************
# Best mean reward updated 22.700 -> 24.100, model saved
# ********************************************************
# steps: 2776
# episodes: 120
# mean 100 episode reward: 23.6
# % time spent exploring: 97
# ********************************************************
# ********************************************************
# steps: 3004
# episodes: 130
# mean 100 episode reward: 23.5
# % time spent exploring: 97
# ********************************************************
# ********************************************************
# steps: 3215
# episodes: 140
# mean 100 episode reward: 23.4
# % time spent exploring: 96
# ********************************************************
# ********************************************************
# steps: 3401
# episodes: 150
# mean 100 episode reward: 23.2
# % time spent exploring: 96
# ********************************************************
# ********************************************************
# steps: 3682
# episodes: 160
# mean 100 episode reward: 23.9
# % time spent exploring: 96
# ********************************************************
# ********************************************************
# steps: 3909
# episodes: 170
# mean 100 episode reward: 23.7
# % time spent exploring: 96
# ********************************************************
# ********************************************************
# steps: 4152
# episodes: 180
# mean 100 episode reward: 24.2
# % time spent exploring: 95
# ********************************************************
# Best mean reward updated 24.100 -> 24.200, model saved
# ********************************************************
# steps: 4384
# episodes: 190
# mean 100 episode reward: 23.7
# % time spent exploring: 95
# ********************************************************
# ********************************************************
# steps: 4573
# episodes: 200
# mean 100 episode reward: 23.4
# % time spent exploring: 95
# ********************************************************
# ********************************************************
# steps: 4732
# episodes: 210
# mean 100 episode reward: 21.6
# % time spent exploring: 95
# ********************************************************
# ********************************************************
# steps: 4954
# episodes: 220
# mean 100 episode reward: 21.8
# % time spent exploring: 95
# ********************************************************
# ********************************************************
# steps: 5170
# episodes: 230
# mean 100 episode reward: 21.7
# % time spent exploring: 94
# ********************************************************
# ********************************************************
# steps: 5384
# episodes: 240
# mean 100 episode reward: 21.7
# % time spent exploring: 94
# ********************************************************
# ********************************************************
# steps: 5620
# episodes: 250
# mean 100 episode reward: 22.2
# % time spent exploring: 94
# ********************************************************
# ********************************************************
# steps: 5874
# episodes: 260
# mean 100 episode reward: 21.9
# % time spent exploring: 94
# ********************************************************
# ********************************************************
# steps: 6097
# episodes: 270
# mean 100 episode reward: 21.9
# % time spent exploring: 93
# ********************************************************
# ********************************************************
# steps: 6395
# episodes: 280
# mean 100 episode reward: 22.4
# % time spent exploring: 93
# ********************************************************
# ********************************************************
# steps: 6642
# episodes: 290
# mean 100 episode reward: 22.6
# % time spent exploring: 93
# ********************************************************
# ********************************************************
# steps: 6855
# episodes: 300
# mean 100 episode reward: 22.8
# % time spent exploring: 93
# ********************************************************
# ********************************************************
# steps: 7083
# episodes: 310
# mean 100 episode reward: 23.5
# % time spent exploring: 92
# ********************************************************
# ********************************************************
# steps: 7317
# episodes: 320
# mean 100 episode reward: 23.6
# % time spent exploring: 92
# ********************************************************
# ********************************************************
# steps: 7575
# episodes: 330
# mean 100 episode reward: 24.0
# % time spent exploring: 92
# ********************************************************
# ********************************************************
# steps: 7735
# episodes: 340
# mean 100 episode reward: 23.5
# % time spent exploring: 92
# ********************************************************
# ********************************************************
# steps: 7966
# episodes: 350
# mean 100 episode reward: 23.5
# % time spent exploring: 92
# ********************************************************
# ********************************************************
# steps: 8179
# episodes: 360
# mean 100 episode reward: 23.0
# % time spent exploring: 91
# ********************************************************
# ********************************************************
# steps: 8385
# episodes: 370
# mean 100 episode reward: 22.9
# % time spent exploring: 91
# ********************************************************
# ********************************************************
# steps: 8645
# episodes: 380
# mean 100 episode reward: 22.5
# % time spent exploring: 91
# ********************************************************
# ********************************************************
# steps: 8880
# episodes: 390
# mean 100 episode reward: 22.4
# % time spent exploring: 91
# ********************************************************
# ********************************************************
# steps: 9186
# episodes: 400
# mean 100 episode reward: 23.3
# % time spent exploring: 90
# ********************************************************
# ********************************************************
# steps: 9413
# episodes: 410
# mean 100 episode reward: 23.3
# % time spent exploring: 90
# ********************************************************
# ********************************************************
# steps: 9633
# episodes: 420
# mean 100 episode reward: 23.2
# % time spent exploring: 90
# ********************************************************
# ********************************************************
# steps: 9919
# episodes: 430
# mean 100 episode reward: 23.4
# % time spent exploring: 90
# ********************************************************
# ********************************************************
# steps: 10106
# episodes: 440
# mean 100 episode reward: 23.7
# % time spent exploring: 89
# ********************************************************
# ********************************************************
# steps: 10315
# episodes: 450
# mean 100 episode reward: 23.5
# % time spent exploring: 89
# ********************************************************
# ********************************************************
# steps: 10554
# episodes: 460
# mean 100 episode reward: 23.8
# % time spent exploring: 89
# ********************************************************
# ********************************************************
# steps: 10819
# episodes: 470
# mean 100 episode reward: 24.3
# % time spent exploring: 89
# ********************************************************
# Best mean reward updated 24.200 -> 24.300, model saved
# ********************************************************
# steps: 10987
# episodes: 480
# mean 100 episode reward: 23.4
# % time spent exploring: 89
# ********************************************************
# ********************************************************
# steps: 11155
# episodes: 490
# mean 100 episode reward: 22.8
# % time spent exploring: 88
# ********************************************************
# ********************************************************
# steps: 11382
# episodes: 500
# mean 100 episode reward: 22.0
# % time spent exploring: 88
# ********************************************************
# ********************************************************
# steps: 11627
# episodes: 510
# mean 100 episode reward: 22.1
# % time spent exploring: 88
# ********************************************************
# ********************************************************
# steps: 11786
# episodes: 520
# mean 100 episode reward: 21.5
# % time spent exploring: 88
# ********************************************************
# ********************************************************
# steps: 12042
# episodes: 530
# mean 100 episode reward: 21.2
# % time spent exploring: 88
# ********************************************************
# ********************************************************
# steps: 12257
# episodes: 540
# mean 100 episode reward: 21.5
# % time spent exploring: 87
# ********************************************************
# ********************************************************
# steps: 12502
# episodes: 550
# mean 100 episode reward: 21.9
# % time spent exploring: 87
# ********************************************************
# ********************************************************
# steps: 12736
# episodes: 560
# mean 100 episode reward: 21.8
# % time spent exploring: 87
# ********************************************************
# ********************************************************
# steps: 12935
# episodes: 570
# mean 100 episode reward: 21.2
# % time spent exploring: 87
# ********************************************************
# ********************************************************
# steps: 13135
# episodes: 580
# mean 100 episode reward: 21.5
# % time spent exploring: 86
# ********************************************************
# ********************************************************
# steps: 13342
# episodes: 590
# mean 100 episode reward: 21.9
# % time spent exploring: 86
# ********************************************************
# ********************************************************
# steps: 13578
# episodes: 600
# mean 100 episode reward: 22.0
# % time spent exploring: 86
# ********************************************************
# ********************************************************
# steps: 13833
# episodes: 610
# mean 100 episode reward: 22.1
# % time spent exploring: 86
# ********************************************************
# ********************************************************
# steps: 14051
# episodes: 620
# mean 100 episode reward: 22.6
# % time spent exploring: 86
# ********************************************************
# ********************************************************
# steps: 14232
# episodes: 630
# mean 100 episode reward: 21.9
# % time spent exploring: 85
# ********************************************************
# ********************************************************
# steps: 14466
# episodes: 640
# mean 100 episode reward: 22.1
# % time spent exploring: 85
# ********************************************************
# ********************************************************
# steps: 14652
# episodes: 650
# mean 100 episode reward: 21.5
# % time spent exploring: 85
# ********************************************************
# ********************************************************
# steps: 14869
# episodes: 660
# mean 100 episode reward: 21.3
# % time spent exploring: 85
# ********************************************************
# ********************************************************
# steps: 15073
# episodes: 670
# mean 100 episode reward: 21.4
# % time spent exploring: 85
# ********************************************************
# ********************************************************
# steps: 15320
# episodes: 680
# mean 100 episode reward: 21.8
# % time spent exploring: 84
# ********************************************************
# ********************************************************
# steps: 15557
# episodes: 690
# mean 100 episode reward: 22.2
# % time spent exploring: 84
# ********************************************************
# ********************************************************
# steps: 15705
# episodes: 700
# mean 100 episode reward: 21.3
# % time spent exploring: 84
# ********************************************************
# ********************************************************
# steps: 15915
# episodes: 710
# mean 100 episode reward: 20.8
# % time spent exploring: 84
# ********************************************************
# ********************************************************
# steps: 16102
# episodes: 720
# mean 100 episode reward: 20.5
# % time spent exploring: 84
# ********************************************************
# ********************************************************
# steps: 16324
# episodes: 730
# mean 100 episode reward: 20.9
# % time spent exploring: 83
# ********************************************************
# ********************************************************
# steps: 16518
# episodes: 740
# mean 100 episode reward: 20.5
# % time spent exploring: 83
# ********************************************************
# ********************************************************
# steps: 16706
# episodes: 750
# mean 100 episode reward: 20.5
# % time spent exploring: 83
# ********************************************************
# ********************************************************
# steps: 16918
# episodes: 760
# mean 100 episode reward: 20.5
# % time spent exploring: 83
# ********************************************************
# ********************************************************
# steps: 17197
# episodes: 770
# mean 100 episode reward: 21.2
# % time spent exploring: 82
# ********************************************************
# ********************************************************
# steps: 17395
# episodes: 780
# mean 100 episode reward: 20.8
# % time spent exploring: 82
# ********************************************************
# ********************************************************
# steps: 17595
# episodes: 790
# mean 100 episode reward: 20.4
# % time spent exploring: 82
# ********************************************************
# ********************************************************
# steps: 17754
# episodes: 800
# mean 100 episode reward: 20.5
# % time spent exploring: 82
# ********************************************************
# ********************************************************
# steps: 17933
# episodes: 810
# mean 100 episode reward: 20.2
# % time spent exploring: 82
# ********************************************************
# ********************************************************
# steps: 18181
# episodes: 820
# mean 100 episode reward: 20.8
# % time spent exploring: 82
# ********************************************************
# ********************************************************
# steps: 18361
# episodes: 830
# mean 100 episode reward: 20.4
# % time spent exploring: 81
# ********************************************************
# ********************************************************
# steps: 18549
# episodes: 840
# mean 100 episode reward: 20.3
# % time spent exploring: 81
# ********************************************************
# ********************************************************
# steps: 18826
# episodes: 850
# mean 100 episode reward: 21.2
# % time spent exploring: 81
# ********************************************************
# ********************************************************
# steps: 19050
# episodes: 860
# mean 100 episode reward: 21.3
# % time spent exploring: 81
# ********************************************************
# ********************************************************
# steps: 19214
# episodes: 870
# mean 100 episode reward: 20.2
# % time spent exploring: 80
# ********************************************************
# ********************************************************
# steps: 19433
# episodes: 880
# mean 100 episode reward: 20.4
# % time spent exploring: 80
# ********************************************************
# ********************************************************
# steps: 19682
# episodes: 890
# mean 100 episode reward: 20.9
# % time spent exploring: 80
# ********************************************************
# ********************************************************
# steps: 19929
# episodes: 900
# mean 100 episode reward: 21.8
# % time spent exploring: 80
# ********************************************************
# ********************************************************
# steps: 20137
# episodes: 910
# mean 100 episode reward: 22.0
# % time spent exploring: 80
# ********************************************************
# ********************************************************
# steps: 20362
# episodes: 920
# mean 100 episode reward: 21.8
# % time spent exploring: 79
# ********************************************************
# ********************************************************
# steps: 20578
# episodes: 930
# mean 100 episode reward: 22.2
# % time spent exploring: 79
# ********************************************************
# ********************************************************
# steps: 20802
# episodes: 940
# mean 100 episode reward: 22.5
# % time spent exploring: 79
# ********************************************************
# ********************************************************
# steps: 21074
# episodes: 950
# mean 100 episode reward: 22.5
# % time spent exploring: 79
# ********************************************************
# ********************************************************
# steps: 21250
# episodes: 960
# mean 100 episode reward: 22.0
# % time spent exploring: 78
# ********************************************************
# ********************************************************
# steps: 21508
# episodes: 970
# mean 100 episode reward: 22.9
# % time spent exploring: 78
# ********************************************************
# ********************************************************
# steps: 21745
# episodes: 980
# mean 100 episode reward: 23.1
# % time spent exploring: 78
# ********************************************************
# ********************************************************
# steps: 21943
# episodes: 990
# mean 100 episode reward: 22.6
# % time spent exploring: 78
# ********************************************************
# ********************************************************
# steps: 22143
# episodes: 1000
# mean 100 episode reward: 22.1
# % time spent exploring: 78
# ********************************************************
# ********************************************************
# steps: 22381
# episodes: 1010
# mean 100 episode reward: 22.4
# % time spent exploring: 77
# ********************************************************
# ********************************************************
# steps: 22666
# episodes: 1020
# mean 100 episode reward: 23.0
# % time spent exploring: 77
# ********************************************************
# ********************************************************
# steps: 22818
# episodes: 1030
# mean 100 episode reward: 22.4
# % time spent exploring: 77
# ********************************************************
# ********************************************************
# steps: 23027
# episodes: 1040
# mean 100 episode reward: 22.2
# % time spent exploring: 77
# ********************************************************
# ********************************************************
# steps: 23274
# episodes: 1050
# mean 100 episode reward: 22.0
# % time spent exploring: 76
# ********************************************************
# ********************************************************
# steps: 23449
# episodes: 1060
# mean 100 episode reward: 22.0
# % time spent exploring: 76
# ********************************************************
# ********************************************************
# steps: 23649
# episodes: 1070
# mean 100 episode reward: 21.4
# % time spent exploring: 76
# ********************************************************
# ********************************************************
# steps: 23925
# episodes: 1080
# mean 100 episode reward: 21.8
# % time spent exploring: 76
# ********************************************************
# ********************************************************
# steps: 24162
# episodes: 1090
# mean 100 episode reward: 22.2
# % time spent exploring: 76
# ********************************************************
# ********************************************************
# steps: 24327
# episodes: 1100
# mean 100 episode reward: 21.8
# % time spent exploring: 75
# ********************************************************
# ********************************************************
# steps: 24505
# episodes: 1110
# mean 100 episode reward: 21.2
# % time spent exploring: 75
# ********************************************************
# ********************************************************
# steps: 24677
# episodes: 1120
# mean 100 episode reward: 20.1
# % time spent exploring: 75
# ********************************************************
# ********************************************************
# steps: 24835
# episodes: 1130
# mean 100 episode reward: 20.2
# % time spent exploring: 75
# ********************************************************
# ********************************************************
# steps: 24986
# episodes: 1140
# mean 100 episode reward: 19.6
# % time spent exploring: 75
# ********************************************************
# ********************************************************
# steps: 25202
# episodes: 1150
# mean 100 episode reward: 19.3
# % time spent exploring: 75
# ********************************************************
# ********************************************************
# steps: 25410
# episodes: 1160
# mean 100 episode reward: 19.6
# % time spent exploring: 74
# ********************************************************
# ********************************************************
# steps: 25628
# episodes: 1170
# mean 100 episode reward: 19.8
# % time spent exploring: 74
# ********************************************************
# ********************************************************
# steps: 25856
# episodes: 1180
# mean 100 episode reward: 19.3
# % time spent exploring: 74
# ********************************************************
# ********************************************************
# steps: 26041
# episodes: 1190
# mean 100 episode reward: 18.8
# % time spent exploring: 74
# ********************************************************
# ********************************************************
# steps: 26265
# episodes: 1200
# mean 100 episode reward: 19.4
# % time spent exploring: 73
# ********************************************************
# ********************************************************
# steps: 26433
# episodes: 1210
# mean 100 episode reward: 19.3
# % time spent exploring: 73
# ********************************************************
# ********************************************************
# steps: 26596
# episodes: 1220
# mean 100 episode reward: 19.2
# % time spent exploring: 73
# ********************************************************
# ********************************************************
# steps: 26810
# episodes: 1230
# mean 100 episode reward: 19.8
# % time spent exploring: 73
# ********************************************************
# ********************************************************
# steps: 26973
# episodes: 1240
# mean 100 episode reward: 19.9
# % time spent exploring: 73
# ********************************************************
# ********************************************************
# steps: 27222
# episodes: 1250
# mean 100 episode reward: 20.2
# % time spent exploring: 73
# ********************************************************
# ********************************************************
# steps: 27473
# episodes: 1260
# mean 100 episode reward: 20.6
# % time spent exploring: 72
# ********************************************************
# ********************************************************
# steps: 27715
# episodes: 1270
# mean 100 episode reward: 20.9
# % time spent exploring: 72
# ********************************************************
# ********************************************************
# steps: 27877
# episodes: 1280
# mean 100 episode reward: 20.2
# % time spent exploring: 72
# ********************************************************
# ********************************************************
# steps: 28060
# episodes: 1290
# mean 100 episode reward: 20.2
# % time spent exploring: 72
# ********************************************************
# ********************************************************
# steps: 28306
# episodes: 1300
# mean 100 episode reward: 20.4
# % time spent exploring: 71
# ********************************************************
# ********************************************************
# steps: 28504
# episodes: 1310
# mean 100 episode reward: 20.7
# % time spent exploring: 71
# ********************************************************
# ********************************************************
# steps: 28674
# episodes: 1320
# mean 100 episode reward: 20.8
# % time spent exploring: 71
# ********************************************************
# ********************************************************
# steps: 28811
# episodes: 1330
# mean 100 episode reward: 20.0
# % time spent exploring: 71
# ********************************************************
# ********************************************************
# steps: 29030
# episodes: 1340
# mean 100 episode reward: 20.6
# % time spent exploring: 71
# ********************************************************
# ********************************************************
# steps: 29197
# episodes: 1350
# mean 100 episode reward: 19.8
# % time spent exploring: 71
# ********************************************************
# ********************************************************
# steps: 29430
# episodes: 1360
# mean 100 episode reward: 19.6
# % time spent exploring: 70
# ********************************************************
# ********************************************************
# steps: 29675
# episodes: 1370
# mean 100 episode reward: 19.6
# % time spent exploring: 70
# ********************************************************
# ********************************************************
# steps: 30046
# episodes: 1380
# mean 100 episode reward: 21.7
# % time spent exploring: 70
# ********************************************************
# ********************************************************
# steps: 30218
# episodes: 1390
# mean 100 episode reward: 21.6
# % time spent exploring: 70
# ********************************************************
# ********************************************************
# steps: 30545
# episodes: 1400
# mean 100 episode reward: 22.4
# % time spent exploring: 69
# ********************************************************
# ********************************************************
# steps: 30794
# episodes: 1410
# mean 100 episode reward: 22.9
# % time spent exploring: 69
# ********************************************************
# ********************************************************
# steps: 30995
# episodes: 1420
# mean 100 episode reward: 23.2
# % time spent exploring: 69
# ********************************************************
# ********************************************************
# steps: 31223
# episodes: 1430
# mean 100 episode reward: 24.1
# % time spent exploring: 69
# ********************************************************
# ********************************************************
# steps: 31532
# episodes: 1440
# mean 100 episode reward: 25.0
# % time spent exploring: 68
# ********************************************************
# Best mean reward updated 24.300 -> 25.000, model saved

# %%
fig, ax = rl_util.init_2d_figure("Reward")
rl_util.plot_graph(
    ax,
    episode_rewards,
    title="reward",
    ylabel="reward",
    save_dir_name=save_dir,
    is_save=True,
)
rl_util.show_figure()
# fig, ax = rl_util.init_2d_figure("Loss")
# rl_util.plot_graph(
#     ax, losses, title="loss", ylabel="loss", save_dir_name=save_dir, is_save=True
# )
# rl_util.show_figure()
# Out:
# Save result/DQN/per/reward_2023_02_12_06_44_41.png

# %%
env = gym.make(env_name, render_mode="human")

test_agent = DQNAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=False,
)

# file_name = save_dir + "CartPole-v1_mean_score.pt"
test_agent.policy_network.load_state_dict(torch.load(save_model_name))

for i_episode in range(1):
    state, _ = env.reset()
    test_reward = 0
    while True:
        env.render()
        action = test_agent.select_action(state, 0.)
        next_state, reward, terminated, truncated, _ = env.step(action)
        test_reward += reward
        state = next_state
        done = terminated or truncated
        if done:
            break
    print(f"{i_episode} episode Total Reward: {test_reward}")
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 3
#       1 env = gym.make(env_name, render_mode="human")
# ----> 3 test_agent = DQNAgent(
#       4     obs_space_shape=env.observation_space.shape,
#       5     action_space_dims=env.action_space.n,
#       6     is_atari=False,
#       7 )
#       9 # file_name = save_dir + "CartPole-v1_mean_score.pt"
#      10 test_agent.policy_network.load_state_dict(torch.load(save_model_name))
#
# File ~/Mygit/2023-RL-Seminar/src/agents/dqn_agent.py:26, in DQNAgent.__init__(self, obs_space_shape, action_space_dims, is_fixed_seed, is_atari, use_double_dqn, config)
#      23 super().__init__(obs_space_shape, action_space_dims, config)
#      25 if is_fixed_seed:
# ---> 26     np.random.seed(config["seed"])
#      27     random.seed(config["seed"])
#      29 self.target_network, self.policy_network = self._get_q_models(
#      30     obs_space_shape, action_space_dims, self.config.device, is_atari
#      31 )
#
# KeyError: 'seed'
