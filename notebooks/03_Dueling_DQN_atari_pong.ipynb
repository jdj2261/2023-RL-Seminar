# %%
import gymnasium as gym
import torch
import numpy as np
import time
import matplotlib.pyplot as plt

from src.utils.util import ShellColor as sc

print(f"{sc.COLOR_PURPLE}Gym version:{sc.ENDC} {gym.__version__}")
print(f"{sc.COLOR_PURPLE}Pytorch version:{sc.ENDC} {torch.__version__}")

from src.agents import DuelingDQNAgent
from src.utils import util as rl_util
# Out:
# Gym version: 0.28.1
# Pytorch version: 2.0.0+cu117

# %%
env_name = "PongNoFrameskip-v4"
env = gym.make(env_name)
env = gym.wrappers.AtariPreprocessing(
    env=env, 
    terminal_on_life_loss=True, 
    grayscale_obs=True, 
    scale_obs=False,
    noop_max=30)
env = gym.wrappers.FrameStack(env, num_stack=4)
rl_util.print_env_info(env=env)
# Out:
# ============ Env Info ===========
# Env id: EnduroNoFrameskip-v4
# Observation space size: (4, 84, 84)
# Action space size: 9
# Action list: ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'DOWN', 'DOWNRIGHT', 'DOWNLEFT', 'RIGHTFIRE', 'LEFTFIRE']
# =================================

# %%
stacked_obs, info = env.reset()
print(stacked_obs.shape)
n_cols = 4
n_rows = 2
fig = plt.figure(figsize=(16, 9))
for row in range(n_rows):
    for col in range(n_cols):
        ax = fig.add_subplot(n_rows, n_cols, row * n_cols + col + 1)
        ax.imshow(stacked_obs[col], cmap="gray")
        stacked_obs, _, _, _,_ = env.step(env.action_space.sample())
plt.show()
# Out:
# (4, 84, 84)

# %%
config = rl_util.create_config()
config["print_frequency"] = 50
config["mean_reward_bound"] = 200
config["device"] = "cuda:0"

# %%
agent = DuelingDQNAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=True,
    config=config,
)

print(agent.config)
print(type(agent.memory))
# Out:
# Model Initializing... An input shape is (4, 84, 84)
# Model Initializing... An input shape is (4, 84, 84)
# ========== Config Info ==========
# n_episodes: 2000
# max_steps: 2000000
# batch_size: 32
# gamma: 0.99
# lr: 0.0001
# start_training_step: 10000
# learning_frequency: 1
# epsilon_start: 0.95
# epsilon_end: 0.01
# epsilon_decay: 300000.0
# seed: 0
# target_update_frequency: 1000
# buffer_size: 50000
# device: cuda:0
# mean_reward_bound: 200
# print_frequency: 50
# =================================
# <class 'src.commons.memory.replay_memory.ReplayMemory'>

# %%
save_dir = "result/DuelingDQN/atari/"
rl_util.create_directory(save_dir)
current_time = rl_util.get_current_time_string()
save_model_name = save_dir + env_name + "_" + current_time + ".pt"

# %%
save_model_name
# Out:
# 'result/DuelingDQN/atari/EnduroNoFrameskip-v4_2023_07_05_02_54_19.pt'

# %%
obs, _ =  env.reset()
episode_returns = []
episode_return = 0
episode_losses = []
episode_loss = 0
episode = 0
best_mean_return = -10000
is_start_train = True

start_time = time.time()
for t in range(agent.config.max_steps):
    epsilon = agent.decay_epsilon(t)
    action = agent.select_action(obs, epsilon)
    next_obs, reward, done, _, _ = env.step(action)
    agent.store_transition(obs, action, reward, next_obs, done)
    episode_return += reward
    
    if t > agent.config.start_training_step:
        if is_start_train:
            print(f"Start Training at timestep {t}...")
            is_start_train = False
            
        episode_loss += agent.update()
        if t % agent.config.target_update_frequency == 0:
            agent.update_target_network()

    if done:
        obs, _ = env.reset()
        episode += 1
        episode_returns.append(episode_return)
        episode_losses.append(episode_loss)
        mean_episode_return = np.mean(episode_returns[-agent.config.print_frequency:])
        mean_episode_loss = np.mean(episode_losses[-agent.config.print_frequency:])

        if episode % agent.config.print_frequency == 0:
            print(
                f"step: {t} | episode: {episode} | cur_return: {episode_return:.4f} | mean_return: {mean_episode_return:.4f} | best_mean_return: {best_mean_return:.4f} | loss: {episode_loss:.4f} | epsilon: {epsilon:.4f}"
            )

        if best_mean_return < mean_episode_return:
            torch.save(agent.policy_network.state_dict(), save_model_name)
            print(f"Best mean return updated {best_mean_return:.3f} -> {mean_episode_return:.3f}, model saved")
            best_mean_return = mean_episode_return
            if mean_episode_return > agent.config.mean_reward_bound:
                print(f"Solved!")
                break
                
        episode_return = 0
        episode_loss = 0
    else:
        obs = next_obs
end_time = time.time()
print(f"WorkingTime[{DuelingDQNAgent.__name__}]: {end_time-start_time:.4f} sec\n")
# Out:
# Best mean return updated -10000.000 -> 0.000, model saved
# Start Training at timestep 10001...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 23
#      20     print(f"Start Training at timestep {t}...")
#      21     is_start_train = False
# ---> 23 episode_loss += agent.update()
#      24 if t % agent.config.target_update_frequency == 0:
#      25     agent.update_target_network()
#
# File ~/Workspace/2023-RL-Seminar/src/agents/dueling_dqn_agent.py:56, in DuelingDQNAgent.update(self)
#      54 actions = torch.from_numpy(actions).long().to(self.config.device).reshape(-1, 1)
#      55 rewards = torch.from_numpy(rewards).float().to(self.config.device).reshape(-1, 1)
# ---> 56 next_states = torch.from_numpy(np.array(next_states)).float().to(self.config.device)
#      57 dones = torch.from_numpy(dones).float().to(self.config.device).reshape(-1, 1)
#      59 cur_q_values = self.policy_network(states).gather(1, actions)
#
# KeyboardInterrupt:

# %%
fig, ax = rl_util.init_2d_figure("Reward")
rl_util.plot_graph(
    ax,
    episode_returns,
    title="reward",
    ylabel="reward",
    save_dir_name=save_dir,
    is_save=True,
)
rl_util.show_figure()
fig, ax = rl_util.init_2d_figure("Loss")
rl_util.plot_graph(
    ax, episode_losses, title="loss", ylabel="loss", save_dir_name=save_dir, is_save=True
)
rl_util.show_figure()
# Out:
# Save result/DuelingDQN/cartpole/reward_2023_07_05_01_38_09.png
# Save result/DuelingDQN/cartpole/loss_2023_07_05_01_38_10.png

# %%
env = gym.make(env_name, render_mode="human")

test_agent = DuelingDQNAgent(
    obs_space_shape=env.observation_space.shape,
    action_space_dims=env.action_space.n,
    is_atari=False,
    config=config
)

# file_name = save_dir + "CartPole-v1_mean_score.pt"
test_agent.policy_network.load_state_dict(torch.load(save_model_name))

for i_episode in range(1):
    state, _ = env.reset()
    test_reward = 0
    while True:
        env.render()
        action = test_agent.select_action(state, 0.)
        next_state, reward, terminated, truncated, _ = env.step(action)
        test_reward += reward
        state = next_state
        done = terminated or truncated
        if done:
            break
    print(f"{i_episode} episode Total Reward: {test_reward}")
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 17
#      15 test_reward = 0
#      16 while True:
# ---> 17     env.render()
#      18     action = test_agent.select_action(state, 0.)
#      19     next_state, reward, terminated, truncated, _ = env.step(action)
#
# File ~/anaconda3/envs/conda_seminar/lib/python3.8/site-packages/gymnasium/core.py:418, in Wrapper.render(self)
#     416 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     417     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 418     return self.env.render()
#
# File ~/anaconda3/envs/conda_seminar/lib/python3.8/site-packages/gymnasium/wrappers/order_enforcing.py:70, in OrderEnforcing.render(self, *args, **kwargs)
#      65 if not self._disable_render_order_enforcing and not self._has_reset:
#      66     raise ResetNeeded(
#      67         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      68         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      69     )
# ---> 70 return self.env.render(*args, **kwargs)
#
# File ~/anaconda3/envs/conda_seminar/lib/python3.8/site-packages/gymnasium/wrappers/env_checker.py:65, in PassiveEnvChecker.render(self, *args, **kwargs)
#      63     return env_render_passive_checker(self.env, *args, **kwargs)
#      64 else:
# ---> 65     return self.env.render(*args, **kwargs)
#
# File ~/anaconda3/envs/conda_seminar/lib/python3.8/site-packages/gymnasium/envs/classic_control/cartpole.py:302, in CartPoleEnv.render(self)
#     300 if self.render_mode == "human":
#     301     pygame.event.pump()
# --> 302     self.clock.tick(self.metadata["render_fps"])
#     303     pygame.display.flip()
#     305 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
